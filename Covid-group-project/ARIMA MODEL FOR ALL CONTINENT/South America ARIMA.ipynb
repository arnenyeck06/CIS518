# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\sonika\anaconda3\lib\site-packages (5.7.0)
# Requirement already satisfied: six in c:\users\sonika\anaconda3\lib\site-packages (from plotly) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\sonika\anaconda3\lib\site-packages (from plotly) (8.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\users\sonika\anaconda3\lib\site-packages (0.19.0)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\sonika\anaconda3\lib\site-packages (from mlxtend) (1.1.0)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\sonika\anaconda3\lib\site-packages (from mlxtend) (1.7.1)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\sonika\anaconda3\lib\site-packages (from mlxtend) (1.3.4)
# Requirement already satisfied: scikit-learn>=0.20.3 in c:\users\sonika\anaconda3\lib\site-packages (from mlxtend) (1.0.2)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\sonika\anaconda3\lib\site-packages (from mlxtend) (1.20.3)
# Requirement already satisfied: setuptools in c:\users\sonika\anaconda3\lib\site-packages (from mlxtend) (58.0.4)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\sonika\anaconda3\lib\site-packages (from mlxtend) (3.4.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\sonika\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sonika\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sonika\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\sonika\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\sonika\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.10.0)
# Requirement already satisfied: six in c:\users\sonika\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\sonika\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2021.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\sonika\anaconda3\lib\site-packages (from scikit-learn>=0.20.3->mlxtend) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install pmdarima
# Out:
# Requirement already satisfied: pmdarima in c:\users\sonika\anaconda3\lib\site-packages (1.8.5)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\sonika\anaconda3\lib\site-packages (from pmdarima) (58.0.4)
# Requirement already satisfied: urllib3 in c:\users\sonika\anaconda3\lib\site-packages (from pmdarima) (1.26.7)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in c:\users\sonika\anaconda3\lib\site-packages (from pmdarima) (0.29.24)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\sonika\anaconda3\lib\site-packages (from pmdarima) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\sonika\anaconda3\lib\site-packages (from pmdarima) (1.1.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\sonika\anaconda3\lib\site-packages (from pmdarima) (1.7.1)
# Requirement already satisfied: statsmodels!=0.12.0,>=0.11 in c:\users\sonika\anaconda3\lib\site-packages (from pmdarima) (0.12.2)
# Requirement already satisfied: pandas>=0.19 in c:\users\sonika\anaconda3\lib\site-packages (from pmdarima) (1.3.4)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\sonika\anaconda3\lib\site-packages (from pmdarima) (1.20.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\sonika\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\sonika\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\sonika\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.19->pmdarima) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\sonika\anaconda3\lib\site-packages (from scikit-learn>=0.22->pmdarima) (2.2.0)
# Requirement already satisfied: patsy>=0.5 in c:\users\sonika\anaconda3\lib\site-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.2)

# %%
pwd
# Out:
# 'C:\\Users\\Sonika\\FINAL RESEARCH'

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
import missingno as msno #
import numpy as np
import statsmodels.api as sm
import plotly.express as px

from statsmodels.tsa.stattools import adfuller, acf, pacf,arma_order_select_ic
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from sklearn.model_selection import train_test_split
from statsmodels.tsa.arima_model import ARIMA
from pmdarima.arima import auto_arima

# %%
df = pd.DataFrame(pd.read_csv('C:\\Users\\Sonika\\FINAL RESEARCH\\sample.csv'))
df
# Out:
#        iso_code     location     date  people_vaccinated_per_hundred
# 0           AFG  Afghanistan  2/24/20                            NaN
# 1           AFG  Afghanistan  2/25/20                            NaN
# 2           AFG  Afghanistan  2/26/20                            NaN
# 3           AFG  Afghanistan  2/27/20                            NaN
# 4           AFG  Afghanistan  2/28/20                            NaN
# ...         ...          ...      ...                            ...
# 181686      ZWE     Zimbabwe  4/21/22                          38.55
# 181687      ZWE     Zimbabwe  4/22/22                          38.58
# 181688      ZWE     Zimbabwe  4/23/22                          38.62
# 181689      ZWE     Zimbabwe  4/24/22                            NaN
# 181690      ZWE     Zimbabwe  4/25/22                            NaN
#
# [181691 rows x 4 columns]

# %%
df.fillna(value = 0,
          inplace = True)

# %%
msno.bar(df)
# Out:
# <AxesSubplot:>

# %%
#Sort dataset by location and search for specific IS0_CODE
df = df.sort_values('location')
ndf=df.loc[df['iso_code'] == 'OWID_SAM' ]

#check dataframe with specific ISO_CODE  
sndf = ndf.sort_values('people_vaccinated_per_hundred')
sndf
# Out:
#         iso_code       location      date  people_vaccinated_per_hundred
# 151297  OWID_SAM  South America  10/29/20                           0.00
# 151047  OWID_SAM  South America   2/22/20                           0.00
# 151048  OWID_SAM  South America   2/23/20                           0.00
# 151049  OWID_SAM  South America   2/24/20                           0.00
# 151050  OWID_SAM  South America   2/25/20                           0.00
# ...          ...            ...       ...                            ...
# 151836  OWID_SAM  South America   4/21/22                          83.91
# 151837  OWID_SAM  South America   4/22/22                          83.92
# 151838  OWID_SAM  South America   4/23/22                          83.93
# 151839  OWID_SAM  South America   4/24/22                          83.93
# 151840  OWID_SAM  South America   4/25/22                          83.93
#
# [794 rows x 4 columns]

# %%
val = sndf['people_vaccinated_per_hundred'].values

# %%
#Plot auto correlation and differencing
plt.rcParams.update({'figure.figsize':(9,7), 'figure.dpi':120})

# Original Series
fig, axes = plt.subplots(3, 2, sharex=True)
axes[0, 0].plot(val); axes[0, 0].set_title('Original Series')
plot_acf(val, ax=axes[0, 1]) 

# 1st Differencing
axes[1, 0].plot(np.diff(val)); axes[1, 0].set_title('1st Order Differencing')
plot_acf(np.diff(val), ax=axes[1, 1])
diffval = np.diff(val)

# 2nd Differencing
axes[2, 0].plot(np.diff(diffval)); axes[2, 0].set_title('2nd Order Differencing')
plot_acf(np.diff(diffval), ax=axes[2, 1])
plt.show()

# %%
model = auto_arima(val, start_p=1, start_q=1,
test='adf', # use Augmented Dickey–Fuller (ADF) test to find optimal 'd'
max_p=3, max_q=3, # maximum p and q
m=1, # frequency of series
d=None, # let model determine 'd'
seasonal=False, # No Seasonality
start_P=0,
D=0,
trace=True,
error_action='ignore',
suppress_warnings=True,
stepwise=True)
print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(0,0,0)[0] intercept   : AIC=-1305.316, Time=0.57 sec
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=-928.571, Time=0.15 sec
#  ARIMA(1,2,0)(0,0,0)[0] intercept   : AIC=-1049.874, Time=0.14 sec
#  ARIMA(0,2,1)(0,0,0)[0] intercept   : AIC=-1294.447, Time=0.26 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=-930.571, Time=0.02 sec
#  ARIMA(2,2,1)(0,0,0)[0] intercept   : AIC=-1310.179, Time=0.73 sec
#  ARIMA(2,2,0)(0,0,0)[0] intercept   : AIC=-1134.322, Time=0.24 sec
#  ARIMA(3,2,1)(0,0,0)[0] intercept   : AIC=-1309.301, Time=1.09 sec
#  ARIMA(2,2,2)(0,0,0)[0] intercept   : AIC=-1311.471, Time=1.75 sec
#  ARIMA(1,2,2)(0,0,0)[0] intercept   : AIC=-1307.172, Time=1.33 sec
#  ARIMA(3,2,2)(0,0,0)[0] intercept   : AIC=-1307.697, Time=1.37 sec
#  ARIMA(2,2,3)(0,0,0)[0] intercept   : AIC=-1311.819, Time=1.90 sec
#  ARIMA(1,2,3)(0,0,0)[0] intercept   : AIC=-1306.884, Time=1.77 sec
#  ARIMA(3,2,3)(0,0,0)[0] intercept   : AIC=-1315.148, Time=2.26 sec
#  ARIMA(3,2,3)(0,0,0)[0]             : AIC=-1350.215, Time=1.56 sec
#  ARIMA(2,2,3)(0,0,0)[0]             : AIC=-1334.234, Time=1.37 sec
#  ARIMA(3,2,2)(0,0,0)[0]             : AIC=-1309.694, Time=0.69 sec
#  ARIMA(2,2,2)(0,0,0)[0]             : AIC=-1313.471, Time=0.74 sec
#
# Best model:  ARIMA(3,2,3)(0,0,0)[0]
# Total fit time: 17.963 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  794
# Model:               SARIMAX(3, 2, 3)   Log Likelihood                 682.108
# Date:                Tue, 26 Apr 2022   AIC                          -1350.215
# Time:                        23:38:12   BIC                          -1317.493
# Sample:                             0   HQIC                         -1337.639
#                                 - 794
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2800      0.028    -10.115      0.000      -0.334      -0.226
# ar.L2         -0.9217      0.012    -75.747      0.000      -0.946      -0.898
# ar.L3          0.1580      0.024      6.533      0.000       0.111       0.205
# ma.L1         -0.4817      0.028    -16.935      0.000      -0.537      -0.426
# ma.L2          0.5770      0.023     25.384      0.000       0.532       0.622
# ma.L3         -0.8803      0.023    -37.555      0.000      -0.926      -0.834
# sigma2         0.0104      0.000     54.956      0.000       0.010       0.011
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.08   Jarque-Bera (JB):            297865.99
# Prob(Q):                              0.77   Prob(JB):                         0.00
# Heteroskedasticity (H):                inf   Skew:                             6.86
# Prob(H) (two-sided):                  0.00   Kurtosis:                        97.01
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# C:\Users\Sonika\anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:3108: RuntimeWarning: divide by zero encountered in double_scalars
#   test_statistic = np.sum(numer_resid) / np.sum(denom_resid)

# %%
##perform diagnostic check for the residual 
model.plot_diagnostics(figsize=(7,5))
plt.show()
# Out:
# C:\Users\Sonika\anaconda3\lib\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)

# %%
# Forecast
n_periods = 50
fc, confint = model.predict(n_periods=n_periods, return_conf_int=True)
index_of_fc = np.arange(len(val), len(val)+n_periods)

# make series for plotting purpose
fc_series = pd.Series(fc, index=index_of_fc)
lower_series = pd.Series(confint[:, 0], index=index_of_fc)
upper_series = pd.Series(confint[:, 1], index=index_of_fc)

# Plot
plt.plot(val)
plt.plot(fc_series, color='darkgreen')
plt.fill_between(lower_series.index,
lower_series,
upper_series,
color='k', alpha=.15)
plt.title("Forecast of Vaccination Rate")
plt.xlabel("Number of Days")
plt.ylabel("Rate")
plt.show()
