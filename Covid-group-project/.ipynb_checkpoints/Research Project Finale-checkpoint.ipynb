# %%
pwd #Check file path
# Out:
# 'C:\\Users\\Sonika\\Research Project on Covid Vaccination rate feature selection'

# %%
pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\users\sonika\anaconda3\lib\site-packages (0.19.0)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\sonika\anaconda3\lib\site-packages (from mlxtend) (1.20.3)
# Requirement already satisfied: setuptools in c:\users\sonika\anaconda3\lib\site-packages (from mlxtend) (58.0.4)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\sonika\anaconda3\lib\site-packages (from mlxtend) (3.4.3)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\sonika\anaconda3\lib\site-packages (from mlxtend) (1.1.0)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\sonika\anaconda3\lib\site-packages (from mlxtend) (1.7.1)
# Requirement already satisfied: scikit-learn>=0.20.3 in c:\users\sonika\anaconda3\lib\site-packages (from mlxtend) (1.0.2)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\sonika\anaconda3\lib\site-packages (from mlxtend) (1.3.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sonika\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sonika\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\sonika\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sonika\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\sonika\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.4)
# Requirement already satisfied: six in c:\users\sonika\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\sonika\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2021.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\sonika\anaconda3\lib\site-packages (from scikit-learn>=0.20.3->mlxtend) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
##Import Libraries
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
import missingno as msno #

# %%
df1 = pd.DataFrame(pd.read_csv('C:\\Users\\Sonika\\Research Project on Covid Vaccination rate feature selection\\covid data.csv'))

# %%
df1
# Out:
#               location      date  total_cases_per_million  \
# 0          Afghanistan  8/1/2021                 3702.759
# 1              Albania  8/1/2021                46336.254
# 2              Algeria  8/1/2021                 3867.706
# 3              Andorra  8/1/2021               189751.015
# 4               Angola  8/1/2021                 1261.728
# ..                 ...       ...                      ...
# 230            Vietnam  8/1/2021                 1604.450
# 231  Wallis and Futuna  8/1/2021                40923.021
# 232              Yemen  8/1/2021                  231.874
# 233             Zambia  8/1/2021                10374.534
# 234           Zimbabwe  8/1/2021                 7258.465
#
#      total_deaths_per_million  reproduction_per_million  \
# 0                     169.121              7.300000e-07
# 1                     855.223              1.720000e-06
# 2                      96.175              1.000000e-06
# 3                    1654.730              9.800000e-07
# 4                      29.941              1.000000e-06
# ..                        ...                       ...
# 230                    13.304              1.280000e-06
# 231                   630.972                       NaN
# 232                    45.161              1.360000e-06
# 233                   180.015              7.300000e-07
# 234                   237.408              7.900000e-07
#
#      icu_patients_per_million  hosp_patients_per_million  total_tests  \
# 0                         NaN                        NaN          NaN
# 1                         NaN                        NaN     0.863664
# 2                       0.852                        NaN          NaN
# 3                         NaN                        NaN          NaN
# 4                         NaN                        NaN          NaN
# ..                        ...                        ...          ...
# 230                       NaN                        NaN          NaN
# 231                       NaN                        NaN          NaN
# 232                       NaN                        NaN          NaN
# 233                       NaN                        NaN     2.095606
# 234                       NaN                        NaN     0.967476
#
#      total_vaccinations  people_vaccinated_per_million  ...  gdp_per_capita  \
# 0                   NaN                            NaN  ...        1803.987
# 1              1.203087                       0.672765  ...       11803.431
# 2                   NaN                            NaN  ...       13913.839
# 3              0.086320                       0.050747  ...             NaN
# 4                   NaN                            NaN  ...        5819.495
# ..                  ...                            ...  ...             ...
# 230            6.415219                       5.756155  ...        6171.884
# 231                 NaN                            NaN  ...             NaN
# 232                 NaN                            NaN  ...        1479.147
# 233            0.438885                       0.285288  ...        3689.251
# 234                 NaN                            NaN  ...        1899.775
#
#      extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0                NaN               0.000597             0.000010
# 1       1.100000e-06               0.000304             0.000010
# 2       5.000000e-07               0.000278             0.000007
# 3                NaN               0.000109             0.000008
# 4                NaN               0.000276             0.000004
# ..               ...                    ...                  ...
# 230     2.000000e-06               0.000245             0.000006
# 231              NaN                    NaN                  NaN
# 232     1.880000e-05               0.000495             0.000005
# 233     5.750000e-05               0.000234             0.000004
# 234     2.140000e-05               0.000308             0.000002
#
#     female_smokers  male_smokers  handwashing_facilities  \
# 0              NaN           NaN                  37.746
# 1     7.100000e-06      0.000051                     NaN
# 2     7.000000e-07      0.000030                  83.741
# 3     2.900000e-05      0.000038                     NaN
# 4              NaN           NaN                  26.664
# ..             ...           ...                     ...
# 230   1.000000e-06      0.000046                  85.847
# 231            NaN           NaN                     NaN
# 232   7.600000e-06      0.000029                  49.542
# 233   3.100000e-06      0.000025                  13.938
# 234   1.600000e-06      0.000031                  36.791
#
#      hospital_beds_per_thousand  human_development_index  \
# 0                  5.000000e-07                    0.511
# 1                  2.890000e-06                    0.795
# 2                  1.900000e-06                    0.748
# 3                           NaN                    0.868
# 4                           NaN                    0.581
# ..                          ...                      ...
# 230                2.600000e-06                    0.704
# 231                         NaN                      NaN
# 232                7.000000e-07                    0.470
# 233                2.000000e-06                    0.584
# 234                1.700000e-06                    0.571
#
#      excess_mortality_cumulative_per_million
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 230                                      NaN
# 231                                      NaN
# 232                                      NaN
# 233                                      NaN
# 234                                      NaN
#
# [235 rows x 27 columns]

# %%
df1.shape
# Out:
# (235, 27)

# %%
df1.dtypes ##Check the datatype for each column
# Out:
# location                                    object
# date                                        object
# total_cases_per_million                    float64
# total_deaths_per_million                   float64
# reproduction_per_million                   float64
# icu_patients_per_million                   float64
# hosp_patients_per_million                  float64
# total_tests                                float64
# total_vaccinations                         float64
# people_vaccinated_per_million              float64
# people_vaccinated                          float64
# total_boosters                             float64
# stringency_index                           float64
# vaccination_rates                          float64
# Vaccine_rate_result                         object
# population                                 float64
# aged_65_older                              float64
# gdp_per_capita                             float64
# extreme_poverty                            float64
# cardiovasc_death_rate                      float64
# diabetes_prevalence                        float64
# female_smokers                             float64
# male_smokers                               float64
# handwashing_facilities                     float64
# hospital_beds_per_thousand                 float64
# human_development_index                    float64
# excess_mortality_cumulative_per_million    float64
# dtype: object

# %%
df1.isna().sum()
# Out:
# location                                     0
# date                                         0
# total_cases_per_million                     16
# total_deaths_per_million                    31
# reproduction_per_million                    51
# icu_patients_per_million                   199
# hosp_patients_per_million                  200
# total_tests                                147
# total_vaccinations                         130
# people_vaccinated_per_million              132
# people_vaccinated                          132
# total_boosters                             209
# stringency_index                            50
# vaccination_rates                          132
# Vaccine_rate_result                        132
# population                                   2
# aged_65_older                               44
# gdp_per_capita                              41
# extreme_poverty                            106
# cardiovasc_death_rate                       42
# diabetes_prevalence                         32
# female_smokers                              90
# male_smokers                                92
# handwashing_facilities                     140
# hospital_beds_per_thousand                  48
# human_development_index                     47
# excess_mortality_cumulative_per_million    189
# dtype: int64

# %%
msno.bar(df1)
# Out:
# <AxesSubplot:>

# %%
df1.fillna(value = 0,
          inplace = True)

# %%
msno.bar(df1)
# Out:
# <AxesSubplot:>

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
#Function to select highly correlated data features
#The function below will list out features that are highly correlated with eachother
def high_corr(dataset,threshold):
    col_corr =  set() #Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j])>threshold:
                colname=corr_matrix.columns[i] #getting the names of the columns
                col_corr.add(colname)
    return col_corr

# %%
corr_features = high_corr(df1,0.7)
len(set(corr_features))
# Out:
# 4

# %%
corr_features
# Out:
# {'people_vaccinated',
#  'people_vaccinated_per_million',
#  'population',
#  'total_deaths_per_million'}

# %%
X= df1.drop(["location","date","Vaccine_rate_result","people_vaccinated","people_vaccinated_per_million",
            "population","total_deaths_per_million"],axis = 1)

# %%
X.corr()
# Out:
#                                          total_cases_per_million  \
# total_cases_per_million                                 1.000000
# reproduction_per_million                                0.248950
# icu_patients_per_million                                0.278770
# hosp_patients_per_million                               0.244538
# total_tests                                             0.157246
# total_vaccinations                                      0.001619
# total_boosters                                          0.036535
# stringency_index                                        0.080413
# vaccination_rates                                       0.442522
# aged_65_older                                           0.419138
# gdp_per_capita                                          0.359197
# extreme_poverty                                        -0.309612
# cardiovasc_death_rate                                  -0.163110
# diabetes_prevalence                                     0.052698
# female_smokers                                          0.501301
# male_smokers                                            0.265474
# handwashing_facilities                                 -0.136467
# hospital_beds_per_thousand                              0.310969
# human_development_index                                 0.319938
# excess_mortality_cumulative_per_million                 0.374368
#
#                                          reproduction_per_million  \
# total_cases_per_million                                  0.248950
# reproduction_per_million                                 1.000000
# icu_patients_per_million                                 0.087185
# hosp_patients_per_million                                0.141787
# total_tests                                              0.129083
# total_vaccinations                                      -0.086041
# total_boosters                                          -0.057727
# stringency_index                                         0.507605
# vaccination_rates                                        0.214739
# aged_65_older                                            0.428690
# gdp_per_capita                                           0.216307
# extreme_poverty                                          0.068603
# cardiovasc_death_rate                                    0.362998
# diabetes_prevalence                                      0.035299
# female_smokers                                           0.302839
# male_smokers                                             0.432134
# handwashing_facilities                                   0.193734
# hospital_beds_per_thousand                               0.429643
# human_development_index                                  0.680495
# excess_mortality_cumulative_per_million                  0.218123
#
#                                          icu_patients_per_million  \
# total_cases_per_million                                  0.278770
# reproduction_per_million                                 0.087185
# icu_patients_per_million                                 1.000000
# hosp_patients_per_million                                0.587547
# total_tests                                              0.260156
# total_vaccinations                                       0.014054
# total_boosters                                          -0.024090
# stringency_index                                         0.162376
# vaccination_rates                                        0.279967
# aged_65_older                                            0.256133
# gdp_per_capita                                           0.192895
# extreme_poverty                                         -0.094277
# cardiovasc_death_rate                                   -0.083579
# diabetes_prevalence                                      0.028142
# female_smokers                                           0.315760
# male_smokers                                             0.165683
# handwashing_facilities                                  -0.141127
# hospital_beds_per_thousand                               0.141489
# human_development_index                                  0.216153
# excess_mortality_cumulative_per_million                  0.168280
#
#                                          hosp_patients_per_million  \
# total_cases_per_million                                   0.244538
# reproduction_per_million                                  0.141787
# icu_patients_per_million                                  0.587547
# hosp_patients_per_million                                 1.000000
# total_tests                                               0.247834
# total_vaccinations                                        0.004486
# total_boosters                                           -0.023193
# stringency_index                                          0.120976
# vaccination_rates                                         0.202952
# aged_65_older                                             0.290266
# gdp_per_capita                                            0.211187
# extreme_poverty                                          -0.096965
# cardiovasc_death_rate                                    -0.037614
# diabetes_prevalence                                       0.066124
# female_smokers                                            0.270661
# male_smokers                                              0.191055
# handwashing_facilities                                   -0.124242
# hospital_beds_per_thousand                                0.139115
# human_development_index                                   0.219220
# excess_mortality_cumulative_per_million                   0.203288
#
#                                          total_tests  total_vaccinations  \
# total_cases_per_million                     0.157246            0.001619
# reproduction_per_million                    0.129083           -0.086041
# icu_patients_per_million                    0.260156            0.014054
# hosp_patients_per_million                   0.247834            0.004486
# total_tests                                 1.000000            0.157035
# total_vaccinations                          0.157035            1.000000
# total_boosters                              0.039437            0.604341
# stringency_index                            0.136803           -0.068112
# vaccination_rates                           0.237654            0.130971
# aged_65_older                               0.202044           -0.046621
# gdp_per_capita                              0.187321           -0.048538
# extreme_poverty                            -0.027040           -0.063376
# cardiovasc_death_rate                      -0.047056           -0.133639
# diabetes_prevalence                         0.047524           -0.104033
# female_smokers                              0.170233           -0.051579
# male_smokers                                0.078313           -0.027177
# handwashing_facilities                     -0.028398           -0.081014
# hospital_beds_per_thousand                  0.062845           -0.035199
# human_development_index                     0.171209           -0.119045
# excess_mortality_cumulative_per_million     0.162855           -0.018316
#
#                                          total_boosters  stringency_index  \
# total_cases_per_million                        0.036535          0.080413
# reproduction_per_million                      -0.057727          0.507605
# icu_patients_per_million                      -0.024090          0.162376
# hosp_patients_per_million                     -0.023193          0.120976
# total_tests                                    0.039437          0.136803
# total_vaccinations                             0.604341         -0.068112
# total_boosters                                 1.000000         -0.080140
# stringency_index                              -0.080140          1.000000
# vaccination_rates                              0.138412          0.199180
# aged_65_older                                 -0.062294          0.236178
# gdp_per_capita                                -0.031249          0.188181
# extreme_poverty                               -0.050888          0.055800
# cardiovasc_death_rate                         -0.109178          0.331472
# diabetes_prevalence                           -0.052748          0.137219
# female_smokers                                -0.008735          0.113131
# male_smokers                                  -0.021133          0.405455
# handwashing_facilities                        -0.066919          0.289506
# hospital_beds_per_thousand                    -0.046554          0.220723
# human_development_index                       -0.083981          0.552456
# excess_mortality_cumulative_per_million       -0.038842          0.078542
#
#                                          vaccination_rates  aged_65_older  \
# total_cases_per_million                           0.442522       0.419138
# reproduction_per_million                          0.214739       0.428690
# icu_patients_per_million                          0.279967       0.256133
# hosp_patients_per_million                         0.202952       0.290266
# total_tests                                       0.237654       0.202044
# total_vaccinations                                0.130971      -0.046621
# total_boosters                                    0.138412      -0.062294
# stringency_index                                  0.199180       0.236178
# vaccination_rates                                 1.000000       0.519800
# aged_65_older                                     0.519800       1.000000
# gdp_per_capita                                    0.479965       0.489820
# extreme_poverty                                  -0.269253      -0.241615
# cardiovasc_death_rate                            -0.191562       0.060910
# diabetes_prevalence                              -0.020074       0.128165
# female_smokers                                    0.448794       0.673050
# male_smokers                                      0.238141       0.419414
# handwashing_facilities                           -0.108568      -0.087964
# hospital_beds_per_thousand                        0.293165       0.590752
# human_development_index                           0.391182       0.608745
# excess_mortality_cumulative_per_million           0.308736       0.424145
#
#                                          gdp_per_capita  extreme_poverty  \
# total_cases_per_million                        0.359197        -0.309612
# reproduction_per_million                       0.216307         0.068603
# icu_patients_per_million                       0.192895        -0.094277
# hosp_patients_per_million                      0.211187        -0.096965
# total_tests                                    0.187321        -0.027040
# total_vaccinations                            -0.048538        -0.063376
# total_boosters                                -0.031249        -0.050888
# stringency_index                               0.188181         0.055800
# vaccination_rates                              0.479965        -0.269253
# aged_65_older                                  0.489820        -0.241615
# gdp_per_capita                                 1.000000        -0.287453
# extreme_poverty                               -0.287453         1.000000
# cardiovasc_death_rate                         -0.185453         0.233851
# diabetes_prevalence                            0.178093        -0.196158
# female_smokers                                 0.346659        -0.188731
# male_smokers                                   0.188744        -0.013513
# handwashing_facilities                        -0.199402         0.011983
# hospital_beds_per_thousand                     0.323361        -0.240669
# human_development_index                        0.436069        -0.059109
# excess_mortality_cumulative_per_million        0.165824        -0.109160
#
#                                          cardiovasc_death_rate  \
# total_cases_per_million                              -0.163110
# reproduction_per_million                              0.362998
# icu_patients_per_million                             -0.083579
# hosp_patients_per_million                            -0.037614
# total_tests                                          -0.047056
# total_vaccinations                                   -0.133639
# total_boosters                                       -0.109178
# stringency_index                                      0.331472
# vaccination_rates                                    -0.191562
# aged_65_older                                         0.060910
# gdp_per_capita                                       -0.185453
# extreme_poverty                                       0.233851
# cardiovasc_death_rate                                 1.000000
# diabetes_prevalence                                   0.248307
# female_smokers                                        0.063267
# male_smokers                                          0.410519
# handwashing_facilities                                0.357144
# hospital_beds_per_thousand                            0.202251
# human_development_index                               0.408946
# excess_mortality_cumulative_per_million              -0.011538
#
#                                          diabetes_prevalence  female_smokers  \
# total_cases_per_million                             0.052698        0.501301
# reproduction_per_million                            0.035299        0.302839
# icu_patients_per_million                            0.028142        0.315760
# hosp_patients_per_million                           0.066124        0.270661
# total_tests                                         0.047524        0.170233
# total_vaccinations                                 -0.104033       -0.051579
# total_boosters                                     -0.052748       -0.008735
# stringency_index                                    0.137219        0.113131
# vaccination_rates                                  -0.020074        0.448794
# aged_65_older                                       0.128165        0.673050
# gdp_per_capita                                      0.178093        0.346659
# extreme_poverty                                    -0.196158       -0.188731
# cardiovasc_death_rate                               0.248307        0.063267
# diabetes_prevalence                                 1.000000        0.098831
# female_smokers                                      0.098831        1.000000
# male_smokers                                        0.155599        0.547495
# handwashing_facilities                              0.115730       -0.164072
# hospital_beds_per_thousand                          0.107245        0.493749
# human_development_index                             0.275028        0.476652
# excess_mortality_cumulative_per_million            -0.019543        0.449831
#
#                                          male_smokers  handwashing_facilities  \
# total_cases_per_million                      0.265474               -0.136467
# reproduction_per_million                     0.432134                0.193734
# icu_patients_per_million                     0.165683               -0.141127
# hosp_patients_per_million                    0.191055               -0.124242
# total_tests                                  0.078313               -0.028398
# total_vaccinations                          -0.027177               -0.081014
# total_boosters                              -0.021133               -0.066919
# stringency_index                             0.405455                0.289506
# vaccination_rates                            0.238141               -0.108568
# aged_65_older                                0.419414               -0.087964
# gdp_per_capita                               0.188744               -0.199402
# extreme_poverty                             -0.013513                0.011983
# cardiovasc_death_rate                        0.410519                0.357144
# diabetes_prevalence                          0.155599                0.115730
# female_smokers                               0.547495               -0.164072
# male_smokers                                 1.000000                0.174326
# handwashing_facilities                       0.174326                1.000000
# hospital_beds_per_thousand                   0.428694                0.007907
# human_development_index                      0.551767                0.209862
# excess_mortality_cumulative_per_million      0.166776               -0.074427
#
#                                          hospital_beds_per_thousand  \
# total_cases_per_million                                    0.310969
# reproduction_per_million                                   0.429643
# icu_patients_per_million                                   0.141489
# hosp_patients_per_million                                  0.139115
# total_tests                                                0.062845
# total_vaccinations                                        -0.035199
# total_boosters                                            -0.046554
# stringency_index                                           0.220723
# vaccination_rates                                          0.293165
# aged_65_older                                              0.590752
# gdp_per_capita                                             0.323361
# extreme_poverty                                           -0.240669
# cardiovasc_death_rate                                      0.202251
# diabetes_prevalence                                        0.107245
# female_smokers                                             0.493749
# male_smokers                                               0.428694
# handwashing_facilities                                     0.007907
# hospital_beds_per_thousand                                 1.000000
# human_development_index                                    0.519498
# excess_mortality_cumulative_per_million                    0.270272
#
#                                          human_development_index  \
# total_cases_per_million                                 0.319938
# reproduction_per_million                                0.680495
# icu_patients_per_million                                0.216153
# hosp_patients_per_million                               0.219220
# total_tests                                             0.171209
# total_vaccinations                                     -0.119045
# total_boosters                                         -0.083981
# stringency_index                                        0.552456
# vaccination_rates                                       0.391182
# aged_65_older                                           0.608745
# gdp_per_capita                                          0.436069
# extreme_poverty                                        -0.059109
# cardiovasc_death_rate                                   0.408946
# diabetes_prevalence                                     0.275028
# female_smokers                                          0.476652
# male_smokers                                            0.551767
# handwashing_facilities                                  0.209862
# hospital_beds_per_thousand                              0.519498
# human_development_index                                 1.000000
# excess_mortality_cumulative_per_million                 0.278455
#
#                                          excess_mortality_cumulative_per_million
# total_cases_per_million                                                 0.374368
# reproduction_per_million                                                0.218123
# icu_patients_per_million                                                0.168280
# hosp_patients_per_million                                               0.203288
# total_tests                                                             0.162855
# total_vaccinations                                                     -0.018316
# total_boosters                                                         -0.038842
# stringency_index                                                        0.078542
# vaccination_rates                                                       0.308736
# aged_65_older                                                           0.424145
# gdp_per_capita                                                          0.165824
# extreme_poverty                                                        -0.109160
# cardiovasc_death_rate                                                  -0.011538
# diabetes_prevalence                                                    -0.019543
# female_smokers                                                          0.449831
# male_smokers                                                            0.166776
# handwashing_facilities                                                 -0.074427
# hospital_beds_per_thousand                                              0.270272
# human_development_index                                                 0.278455
# excess_mortality_cumulative_per_million                                 1.000000

# %%
y = df1["Vaccine_rate_result"]

# %%
y
# Out:
# 0             0
# 1      very low
# 2             0
# 3          high
# 4             0
#          ...
# 230    very low
# 231           0
# 232           0
# 233    very low
# 234           0
# Name: Vaccine_rate_result, Length: 235, dtype: object

# %%
#Separate datasets into train and test
from sklearn.model_selection import train_test_split
X_train,X_test,y_test,y_test = train_test_split(X,y,test_size = 0.3,random_state = 0)
X_train.shape , X_test.shape
# Out:
# ((164, 20), (71, 20))

# %%
## FEATURE SELECTION USING WRAPPER METHOD forward selection and backward elimination
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression() #Instantiate the model

# %%
from mlxtend.feature_selection import SequentialFeatureSelector #library for forward and backward

# %%
sfs =  SequentialFeatureSelector(lr,k_features=10, forward = True, scoring = "accuracy") #instantiate the feature selection model

# %%
sfs.fit(X,y)
# Out:
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\mlxtend\feature_selection\sequential_feature_selector.py:612: RuntimeWarning: Mean of empty slice
#   all_avg_scores.append(np.nanmean(cv_scores))
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
# ...
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\mlxtend\feature_selection\sequential_feature_selector.py:612: RuntimeWarning: Mean of empty slice
#   all_avg_scores.append(np.nanmean(cv_scores))
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 979, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#   File "C:\Users\Sonika\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 997, in _check_y
#     y = y.astype(np.float64)
# ValueError: could not convert string to float: 'very low'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Sonika\anaconda3\lib\site-packages\mlxtend\feature_selection\sequential_feature_selector.py:612: RuntimeWarning: Mean of empty slice
#   all_avg_scores.append(np.nanmean(cv_scores))
# SequentialFeatureSelector(estimator=LinearRegression(), k_features=10,
#                           scoring='accuracy')

# %%
sfs.k_feature_names_
# Out:
# ('total_cases_per_million',
#  'reproduction_per_million',
#  'icu_patients_per_million',
#  'hosp_patients_per_million',
#  'total_tests',
#  'total_vaccinations',
#  'total_boosters',
#  'stringency_index',
#  'vaccination_rates',
#  'aged_65_older')
