# %% [markdown]
# # COVID-19 GLOBAL VACCINATION RATES:PREDICTIVE ANALYSIS

# %% [markdown]
# ## Importing necessary libraries required for our project

# %%
import pandas as pd

# %% [markdown]
# ## Read the dataset from CSV file

# %% [markdown]
# ####  Now let us read the dataset we chose for this project. We got our data sets from Our world in data. It contained various data on different predictor such as gdp,hdi,death,vaccine etc. We will only be using the predictors we think are necessary for this project.

# %%
df= pd.read_csv(r'C:\Users\Sonika\Documents\Spring 2022\CIS 518\Research_Project\OWID_COVID_DATA.csv')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [2], in <module>
# ----> 1 df= pd.read_csv(r'C:\Users\Sonika\Documents\Spring 2022\CIS 518\Research_Project\OWID_COVID_DATA.csv')
#       2 df
#
# File ~/Desktop/Repositories/machine_learning/sample_project/env/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
df.shape
# Out:
# (168164, 67)

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# #### In this process we will be cleaning our data. We will be finding our null values, drop unnecessary columns, separate the datasets in to smaller data sets and so on.

# %% [markdown]
# ### a) Use .drop() to drop the columns that are not required for our analysis

# %%
df1 = df.drop({'total_cases','new_cases','new_cases_smoothed','new_deaths','new_deaths_smoothed','total_cases_per_million',
              'new_cases_per_million','new_cases_smoothed_per_million','total_deaths_per_million','new_deaths_per_million',
              'reproduction_rate', 'icu_patients', 'icu_patients_per_million', 'hosp_patients', 'hosp_patients_per_million',
              'weekly_icu_admissions','weekly_icu_admissions_per_million','weekly_hosp_admissions','weekly_hosp_admissions_per_million',
              'total_tests','new_tests', 'total_tests_per_thousand', 'new_tests_per_thousand','new_tests_smoothed','new_tests_smoothed_per_thousand',
              'positive_rate','tests_per_case','tests_units','total_vaccinations_per_hundred','people_vaccinated_per_hundred', 
              'people_fully_vaccinated_per_hundred','total_boosters_per_hundred','new_vaccinations_smoothed_per_million', 
              'new_people_vaccinated_smoothed','new_people_vaccinated_smoothed_per_hundred','aged_70_older','female_smokers',
              'male_smokers','handwashing_facilities','hospital_beds_per_thousand','life_expectancy','human_development_index',
              'excess_mortality','excess_mortality_cumulative_per_million'} , axis = 1)

# %%
df1
# Out:
#        iso_code continent     location     date  total_deaths  \
# 0           AFG      Asia  Afghanistan  2/24/20           NaN
# 1           AFG      Asia  Afghanistan  2/25/20           NaN
# 2           AFG      Asia  Afghanistan  2/26/20           NaN
# 3           AFG      Asia  Afghanistan  2/27/20           NaN
# 4           AFG      Asia  Afghanistan  2/28/20           NaN
# ...         ...       ...          ...      ...           ...
# 168159      ZWE    Africa     Zimbabwe   3/9/22        5400.0
# 168160      ZWE    Africa     Zimbabwe  3/10/22        5408.0
# 168161      ZWE    Africa     Zimbabwe  3/11/22        5408.0
# 168162      ZWE    Africa     Zimbabwe  3/12/22        5412.0
# 168163      ZWE    Africa     Zimbabwe  3/13/22        5414.0
#
#         new_deaths_smoothed_per_million  total_vaccinations  \
# 0                                   NaN                 NaN
# 1                                   NaN                 NaN
# ...

# %%
df1.shape
# Out:
# (168164, 23)

# %% [markdown]
# ### b) Extract the necessary data into different Excel sheet to perform analysis using Megastat

# %% [markdown]
# ##### Extrat the data that contains OWID_AFR. OWID_AFR contains all average data of the african countries perday.

# %%
OWID_AFRICA = df1[df1['iso_code'].str.contains('OWID_AFR')]

# %%
OWID_AFRICA
# Out:
#       iso_code continent location     date  total_deaths  \
# 749   OWID_AFR       NaN   Africa  2/13/20           NaN
# 750   OWID_AFR       NaN   Africa  2/14/20           NaN
# 751   OWID_AFR       NaN   Africa  2/15/20           NaN
# 752   OWID_AFR       NaN   Africa  2/16/20           NaN
# 753   OWID_AFR       NaN   Africa  2/17/20           NaN
# ...        ...       ...      ...      ...           ...
# 1504  OWID_AFR       NaN   Africa   3/9/22      250636.0
# 1505  OWID_AFR       NaN   Africa  3/10/22      250750.0
# 1506  OWID_AFR       NaN   Africa  3/11/22      250810.0
# 1507  OWID_AFR       NaN   Africa  3/12/22      250839.0
# 1508  OWID_AFR       NaN   Africa  3/13/22      250887.0
#
#       new_deaths_smoothed_per_million  total_vaccinations  people_vaccinated  \
# 749                               NaN                 NaN                NaN
# 750                               NaN                 NaN                NaN
# ...

# %% [markdown]
# ##### Extrat the data that contains OWID_SAM. OWID_SAM contains all average data of the Southern American countries perday.

# %%
OWID_S_AMERICA = df1[df1['iso_code'].str.contains('OWID_SAM')]
OWID_S_AMERICA
# Out:
#         iso_code continent       location     date  total_deaths  \
# 140268  OWID_SAM       NaN  South America  2/22/20           NaN
# 140269  OWID_SAM       NaN  South America  2/23/20           NaN
# 140270  OWID_SAM       NaN  South America  2/24/20           NaN
# 140271  OWID_SAM       NaN  South America  2/25/20           NaN
# 140272  OWID_SAM       NaN  South America  2/26/20           NaN
# ...          ...       ...            ...      ...           ...
# 141014  OWID_SAM       NaN  South America   3/9/22     1265006.0
# 141015  OWID_SAM       NaN  South America  3/10/22     1266078.0
# 141016  OWID_SAM       NaN  South America  3/11/22     1266692.0
# 141017  OWID_SAM       NaN  South America  3/12/22     1267257.0
# 141018  OWID_SAM       NaN  South America  3/13/22     1267893.0
#
#         new_deaths_smoothed_per_million  total_vaccinations  \
# 140268                              NaN                 NaN
# 140269                              NaN                 NaN
# ...

# %% [markdown]
# ##### Extrat the data that contains OWID_OCE. OWID_OCE contains all average data of the countries in Oceania perday.

# %%
OWID_OCEANIA = df1[df1['iso_code'].str.contains('OWID_OCE')]
OWID_OCEANIA
# Out:
#         iso_code continent location     date  total_deaths  \
# 115134  OWID_OCE       NaN  Oceania  1/25/20           NaN
# 115135  OWID_OCE       NaN  Oceania  1/26/20           NaN
# 115136  OWID_OCE       NaN  Oceania  1/27/20           NaN
# 115137  OWID_OCE       NaN  Oceania  1/28/20           NaN
# 115138  OWID_OCE       NaN  Oceania  1/29/20           NaN
# ...          ...       ...      ...      ...           ...
# 115908  OWID_OCE       NaN  Oceania   3/9/22        8150.0
# 115909  OWID_OCE       NaN  Oceania  3/10/22        8196.0
# 115910  OWID_OCE       NaN  Oceania  3/11/22        8230.0
# 115911  OWID_OCE       NaN  Oceania  3/12/22        8256.0
# 115912  OWID_OCE       NaN  Oceania  3/13/22        8262.0
#
#         new_deaths_smoothed_per_million  total_vaccinations  \
# 115134                              NaN                 NaN
# 115135                              NaN                 NaN
# 115136                              NaN                 NaN
# ...

# %% [markdown]
# ##### Extrat the data that contains OWID_NAM. OWID_NAM contains all average data of the Northern American countries perday.

# %%
OWID_N_AMERICA = df1[df1['iso_code'].str.contains('OWID_NAM')]
OWID_N_AMERICA
# Out:
#         iso_code continent       location     date  total_deaths  \
# 112540  OWID_NAM       NaN  North America  1/22/20           NaN
# 112541  OWID_NAM       NaN  North America  1/23/20           NaN
# 112542  OWID_NAM       NaN  North America  1/24/20           NaN
# 112543  OWID_NAM       NaN  North America  1/25/20           NaN
# 112544  OWID_NAM       NaN  North America  1/26/20           NaN
# ...          ...       ...            ...      ...           ...
# 113317  OWID_NAM       NaN  North America   3/9/22     1393602.0
# 113318  OWID_NAM       NaN  North America  3/10/22     1395529.0
# 113319  OWID_NAM       NaN  North America  3/11/22     1397269.0
# 113320  OWID_NAM       NaN  North America  3/12/22     1398156.0
# 113321  OWID_NAM       NaN  North America  3/13/22     1398403.0
#
#         new_deaths_smoothed_per_million  total_vaccinations  \
# 112540                              NaN                 NaN
# 112541                              NaN                 NaN
# ...

# %% [markdown]
# ##### Extrat the data that contains OWID_ASI. OWID_ASI contains all average data of the ASIAN countries perday.

# %%
OWID_ASIA = df1[df1['iso_code'].str.contains('OWID_ASI')]
OWID_ASIA
# Out:
#       iso_code continent location     date  total_deaths  \
# 8222  OWID_ASI       NaN     Asia  1/22/20          17.0
# 8223  OWID_ASI       NaN     Asia  1/23/20          18.0
# 8224  OWID_ASI       NaN     Asia  1/24/20          26.0
# 8225  OWID_ASI       NaN     Asia  1/25/20          42.0
# 8226  OWID_ASI       NaN     Asia  1/26/20          56.0
# ...        ...       ...      ...      ...           ...
# 8999  OWID_ASI       NaN     Asia   3/9/22     1370904.0
# 9000  OWID_ASI       NaN     Asia  3/10/22     1372854.0
# 9001  OWID_ASI       NaN     Asia  3/11/22     1374651.0
# 9002  OWID_ASI       NaN     Asia  3/12/22     1376303.0
# 9003  OWID_ASI       NaN     Asia  3/13/22     1377867.0
#
#       new_deaths_smoothed_per_million  total_vaccinations  people_vaccinated  \
# 8222                              NaN                 NaN                NaN
# 8223                              NaN                 NaN                NaN
# ...

# %% [markdown]
# ##### Extrat the data that contains OWID_EUR. OWID_EUR contains all average data of the European countries perday.

# %%
OWID_EUROPE = df1[df1['iso_code'].str.contains('OWID_EUR')]
OWID_EUROPE
# Out:
#        iso_code continent location     date  total_deaths  \
# 49871  OWID_EUR       NaN   Europe  1/23/20           NaN
# 49872  OWID_EUR       NaN   Europe  1/24/20           NaN
# 49873  OWID_EUR       NaN   Europe  1/25/20           NaN
# 49874  OWID_EUR       NaN   Europe  1/26/20           NaN
# 49875  OWID_EUR       NaN   Europe  1/27/20           NaN
# ...         ...       ...      ...      ...           ...
# 50647  OWID_EUR       NaN   Europe   3/9/22     1734090.0
# 50648  OWID_EUR       NaN   Europe  3/10/22     1736367.0
# 50649  OWID_EUR       NaN   Europe  3/11/22     1738531.0
# 50650  OWID_EUR       NaN   Europe  3/12/22     1739839.0
# 50651  OWID_EUR       NaN   Europe  3/13/22     1740865.0
#
#        new_deaths_smoothed_per_million  total_vaccinations  people_vaccinated  \
# 49871                              NaN                 NaN                NaN
# 49872                              NaN                 NaN                NaN
# ...

# %% [markdown]
# ### Extract data from various Continents

# %% [markdown]
# ##### 1. South America

# %%
 SouthAmerica = df1[df1['continent']=='South America']
 SouthAmerica
# Out:
#        iso_code      continent   location     date  total_deaths  \
# 5918        ARG  South America  Argentina   1/1/20           NaN
# 5919        ARG  South America  Argentina   1/2/20           NaN
# 5920        ARG  South America  Argentina   1/3/20           NaN
# 5921        ARG  South America  Argentina   1/4/20           NaN
# 5922        ARG  South America  Argentina   1/5/20           NaN
# ...         ...            ...        ...      ...           ...
# 163932      VEN  South America  Venezuela   3/9/22        5652.0
# 163933      VEN  South America  Venezuela  3/10/22        5655.0
# 163934      VEN  South America  Venezuela  3/11/22        5655.0
# 163935      VEN  South America  Venezuela  3/12/22        5656.0
# 163936      VEN  South America  Venezuela  3/13/22        5658.0
#
#         new_deaths_smoothed_per_million  total_vaccinations  \
# 5918                                NaN                 NaN
# 5919                                NaN                 NaN
# ...

# %% [markdown]
# ##### 2. North America

# %%
 NorthAmerica = df1[df1['continent']=='North America']
 NorthAmerica
# Out:
#        iso_code      continent       location     date  total_deaths  \
# 4471        AIA  North America       Anguilla  3/28/20           NaN
# 4472        AIA  North America       Anguilla  3/29/20           NaN
# 4473        AIA  North America       Anguilla  3/30/20           NaN
# 4474        AIA  North America       Anguilla  3/31/20           NaN
# 4475        AIA  North America       Anguilla   4/1/20           NaN
# ...         ...            ...            ...      ...           ...
# 159733      USA  North America  United States   3/9/22      963819.0
# 159734      USA  North America  United States  3/10/22      965464.0
# 159735      USA  North America  United States  3/11/22      967165.0
# 159736      USA  North America  United States  3/12/22      967552.0
# 159737      USA  North America  United States  3/13/22      967720.0
#
#         new_deaths_smoothed_per_million  total_vaccinations  \
# 4471                                NaN                 NaN
# ...

# %% [markdown]
# ##### 3. Asia

# %%
 Asia = df1[df1['continent']=='Asia']
Asia
# Out:
#        iso_code continent     location     date  total_deaths  \
# 0           AFG      Asia  Afghanistan  2/24/20           NaN
# 1           AFG      Asia  Afghanistan  2/25/20           NaN
# 2           AFG      Asia  Afghanistan  2/26/20           NaN
# 3           AFG      Asia  Afghanistan  2/27/20           NaN
# 4           AFG      Asia  Afghanistan  2/28/20           NaN
# ...         ...       ...          ...      ...           ...
# 166709      YEM      Asia        Yemen   3/9/22        2138.0
# 166710      YEM      Asia        Yemen  3/10/22        2139.0
# 166711      YEM      Asia        Yemen  3/11/22        2139.0
# 166712      YEM      Asia        Yemen  3/12/22        2139.0
# 166713      YEM      Asia        Yemen  3/13/22        2139.0
#
#         new_deaths_smoothed_per_million  total_vaccinations  \
# 0                                   NaN                 NaN
# 1                                   NaN                 NaN
# ...

# %% [markdown]
# ##### 4. Africa

# %%
 Africa = df1[df1['continent']=='Africa']
 Africa
# Out:
#        iso_code continent  location     date  total_deaths  \
# 2257        DZA    Africa   Algeria  2/25/20           NaN
# 2258        DZA    Africa   Algeria  2/26/20           NaN
# 2259        DZA    Africa   Algeria  2/27/20           NaN
# 2260        DZA    Africa   Algeria  2/28/20           NaN
# 2261        DZA    Africa   Algeria  2/29/20           NaN
# ...         ...       ...       ...      ...           ...
# 168159      ZWE    Africa  Zimbabwe   3/9/22        5400.0
# 168160      ZWE    Africa  Zimbabwe  3/10/22        5408.0
# 168161      ZWE    Africa  Zimbabwe  3/11/22        5408.0
# 168162      ZWE    Africa  Zimbabwe  3/12/22        5412.0
# 168163      ZWE    Africa  Zimbabwe  3/13/22        5414.0
#
#         new_deaths_smoothed_per_million  total_vaccinations  \
# 2257                                NaN                 NaN
# 2258                                NaN                 NaN
# 2259                                NaN                 NaN
# ...

# %% [markdown]
# ##### 5. Oceania

# %%
 Oceania = df1[df1['continent']=='Oceania']
 Oceania
# Out:
#        iso_code continent           location     date  total_deaths  \
# 9004        AUS   Oceania          Australia  1/26/20           NaN
# 9005        AUS   Oceania          Australia  1/27/20           NaN
# 9006        AUS   Oceania          Australia  1/28/20           NaN
# 9007        AUS   Oceania          Australia  1/29/20           NaN
# 9008        AUS   Oceania          Australia  1/30/20           NaN
# ...         ...       ...                ...      ...           ...
# 165224      WLF   Oceania  Wallis and Futuna   3/9/22           7.0
# 165225      WLF   Oceania  Wallis and Futuna  3/10/22           7.0
# 165226      WLF   Oceania  Wallis and Futuna  3/11/22           7.0
# 165227      WLF   Oceania  Wallis and Futuna  3/12/22           7.0
# 165228      WLF   Oceania  Wallis and Futuna  3/13/22           7.0
#
#         new_deaths_smoothed_per_million  total_vaccinations  \
# 9004                                NaN                 NaN
# ...

# %% [markdown]
# ##### 6. Europe

# %%
 Europe = df1[df1['continent']=='Europe']
 Europe
# Out:
#        iso_code continent location     date  total_deaths  \
# 1509        ALB    Europe  Albania  2/25/20           NaN
# 1510        ALB    Europe  Albania  2/26/20           NaN
# 1511        ALB    Europe  Albania  2/27/20           NaN
# 1512        ALB    Europe  Albania  2/28/20           NaN
# 1513        ALB    Europe  Albania  2/29/20           NaN
# ...         ...       ...      ...      ...           ...
# 163202      VAT    Europe  Vatican   3/9/22           NaN
# 163203      VAT    Europe  Vatican  3/10/22           NaN
# 163204      VAT    Europe  Vatican  3/11/22           NaN
# 163205      VAT    Europe  Vatican  3/12/22           NaN
# 163206      VAT    Europe  Vatican  3/13/22           NaN
#
#         new_deaths_smoothed_per_million  total_vaccinations  \
# 1509                                NaN                 NaN
# 1510                                NaN                 NaN
# 1511                                NaN                 NaN
# ...

# %% [markdown]
# # Use .to_csv to export the separated dataset to excelsheet

# %%
OWID_ASIA.to_csv(r'C:\Users\Sonika\Documents\Spring 2022\CIS 518\Research_Project\OWID_ASIA.csv')

# %%
OWID_AFRICA.to_csv(r'C:\Users\Sonika\Documents\Spring 2022\CIS 518\Research_Project\OWID_AFRICA.csv')

# %%
OWID_S_AMERICA.to_csv(r'C:\Users\Sonika\Documents\Spring 2022\CIS 518\Research_Project\OWID_S_AMERICA.csv')

# %%
OWID_N_AMERICA.to_csv(r'C:\Users\Sonika\Documents\Spring 2022\CIS 518\Research_Project\OWID_N_AMERICA.csv')

# %%
OWID_OCEANIA.to_csv(r'C:\Users\Sonika\Documents\Spring 2022\CIS 518\Research_Project\OWID_OCEANIA.csv')

# %%
NorthAmerica.to_csv(r'C:\Users\Sonika\Documents\Spring 2022\CIS 518\Research_Project\North America.csv')

# %%
SouthAmerica.to_csv(r'C:\Users\Sonika\Documents\Spring 2022\CIS 518\Research_Project\South America.csv')

# %%
Asia.to_csv(r'C:\Users\Sonika\Documents\Spring 2022\CIS 518\Research_Project\Asia.csv')

# %%
Africa.to_csv(r'C:\Users\Sonika\Documents\Spring 2022\CIS 518\Research_Project\Africa.csv')

# %%
Oceania.to_csv(r'C:\Users\Sonika\Documents\Spring 2022\CIS 518\Research_Project\Oceania.csv')
