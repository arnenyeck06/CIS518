# %% [markdown]
# # TASK 1

# %% [markdown]
# ## a. Import required libraries

# %%
import pandas as pd
import missingno as msno #Finds null values
import numpy as np #Replace nulls
import seaborn as sns #For boxplot to find outliers
import matplotlib.pyplot as plt #to resize the figures
import regex as re # importing regex library to delete repetitive name in each row
from scipy import stats

# %% [markdown]
# ## b. Read data file

# %%
df = pd.read_csv(r'C:\Users\Sonika\Documents\Spring 2022\CIS 518\project_1\project_1\project1_ds.csv',index_col = 'X.')
df #Call the dataset
# Out:
#      Unnamed: 0                   Name   Type.1  Type.2  Total  HP  Attack  \
# X.
# 1             1              Bulbasaur    Grass  Poison    318  45      49
# 2             2                Ivysaur    Grass  Poison    405  60      62
# 3             3               Venusaur    Grass  Poison    525  80      82
# 3             4  VenusaurMega Venusaur    Grass  Poison    625  80     100
# 4             5             Charmander     Fire     NaN    309  39      52
# ..          ...                    ...      ...     ...    ...  ..     ...
# 719         796                Diancie     Rock   Fairy    600  50     100
# 719         797    DiancieMega Diancie     Rock   Fairy    700  50     160
# 720         798    HoopaHoopa Confined  Psychic   Ghost    600  80     110
# 720         799     HoopaHoopa Unbound  Psychic    Dark    680  80     160
# 721         800              Volcanion     Fire   Water    600  80     110
#
#      Defense  Sp..Atk  Sp..Def  Speed  Generation  Legendary  Win_rate  \
# X.
# 1         49       65       65     45           1      False      0.17
# 2         63       80       80     60           1      False      0.36
# 3         83      100      100     80           1      False      0.63
# 3        123      122      120     80           1      False      0.58
# 4         43       60       50     65           1      False      0.48
# ..       ...      ...      ...    ...         ...        ...       ...
# 719      150      100      150     50           6       True       NaN
# 719      110      160      110    110           6       True       NaN
# 720       60      150      130     70           6       True       NaN
# 720       60      170      130     80           6       True       NaN
# 721      120      130       90     70           6       True       NaN
#
#      Type1_Win_rate
# X.
# 1          0.446002
# 2          0.446002
# 3          0.446002
# 3          0.446002
# 4          0.441195
# ..              ...
# 719        0.519051
# 719        0.519051
# 720        0.400652
# 720        0.400652
# 721        0.441195
#
# [800 rows x 15 columns]

# %% [markdown]
# ## c. Check the dataframe shape

# %%
df.shape ##Check for number of rows and columns
# Out:
# (800, 15)

# %% [markdown]
# ## d.Make Dataframe more readable

# %%
df1 = df.drop('Unnamed: 0', axis = 1) ## Dropping Column Unnamed: 0 to level the rows
df1
# Out:
#                       Name   Type.1  Type.2  Total  HP  Attack  Defense  \
# X.
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp..Atk  Sp..Def  Speed  Generation  Legendary  Win_rate  Type1_Win_rate
# X.
# 1         65       65     45           1      False      0.17        0.446002
# 2         80       80     60           1      False      0.36        0.446002
# 3        100      100     80           1      False      0.63        0.446002
# 3        122      120     80           1      False      0.58        0.446002
# 4         60       50     65           1      False      0.48        0.441195
# ..       ...      ...    ...         ...        ...       ...             ...
# 719      100      150     50           6       True       NaN        0.519051
# 719      160      110    110           6       True       NaN        0.519051
# 720      150      130     70           6       True       NaN        0.400652
# 720      170      130     80           6       True       NaN        0.400652
# 721      130       90     70           6       True       NaN        0.441195
#
# [800 rows x 14 columns]

# %%
sorted_df1 = df1.sort_values(by= 'Name') #Sorted by Pokemon's name

# %%
sorted_df1.duplicated() #Check for any duplicate rows
# Out:
# X.
# 460    False
# 460    False
# 63     False
# 359    False
# 359    False
#        ...
# 571    False
# 570    False
# 41     False
# 634    False
# 718    False
# Length: 800, dtype: bool

# %%
#To rename Attributes  

df1.rename({'Type.1': 'Type 1',\

           'Type.2': 'Type 2',\

           'Sp..Atk': 'Special_Attack',\

           'Sp..Def': 'Special_Defense'}, axis=1, inplace = True) 

df1
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# X.
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Special_Attack  Special_Defense  Speed  Generation  Legendary  Win_rate  \
# X.
# 1                65               65     45           1      False      0.17
# 2                80               80     60           1      False      0.36
# 3               100              100     80           1      False      0.63
# 3               122              120     80           1      False      0.58
# 4                60               50     65           1      False      0.48
# ..              ...              ...    ...         ...        ...       ...
# 719             100              150     50           6       True       NaN
# 719             160              110    110           6       True       NaN
# 720             150              130     70           6       True       NaN
# 720             170              130     80           6       True       NaN
# 721             130               90     70           6       True       NaN
#
#      Type1_Win_rate
# X.
# 1          0.446002
# 2          0.446002
# 3          0.446002
# 3          0.446002
# 4          0.441195
# ..              ...
# 719        0.519051
# 719        0.519051
# 720        0.400652
# 720        0.400652
# 721        0.441195
#
# [800 rows x 14 columns]

# %%
##delete repetitive name in each row
df1.Name = df1.Name.apply(lambda x: re.sub(r'(.+)(Mega.+)',r'\2', x)) 

df1.head()
# Out:
#              Name Type 1  Type 2  Total  HP  Attack  Defense  Special_Attack  \
# X.
# 1       Bulbasaur  Grass  Poison    318  45      49       49              65
# 2         Ivysaur  Grass  Poison    405  60      62       63              80
# 3        Venusaur  Grass  Poison    525  80      82       83             100
# 3   Mega Venusaur  Grass  Poison    625  80     100      123             122
# 4      Charmander   Fire     NaN    309  39      52       43              60
#
#     Special_Defense  Speed  Generation  Legendary  Win_rate  Type1_Win_rate
# X.
# 1                65     45           1      False      0.17        0.446002
# 2                80     60           1      False      0.36        0.446002
# 3               100     80           1      False      0.63        0.446002
# 3               120     80           1      False      0.58        0.446002
# 4                50     65           1      False      0.48        0.441195

# %% [markdown]
# ## e.Check data types for each column

# %%
df1.dtypes ##Check the datatype for each column
# Out:
# Name                object
# Type 1              object
# Type 2              object
# Total                int64
# HP                   int64
# Attack               int64
# Defense              int64
# Special_Attack       int64
# Special_Defense      int64
# Speed                int64
# Generation           int64
# Legendary             bool
# Win_rate           float64
# Type1_Win_rate     float64
# dtype: object

# %% [markdown]
# # TASK 2

# %% [markdown]
# ## a. Find any missing values using missingno

# %%
df1.isna().sum() #Shows total number of null values in each columns
# Out:
# Name                 0
# Type 1               0
# Type 2             386
# Total                0
# HP                   0
# Attack               0
# Defense              0
# Special_Attack       0
# Special_Defense      0
# Speed                0
# Generation           0
# Legendary            0
# Win_rate            94
# Type1_Win_rate       0
# dtype: int64

# %%
msno.matrix(df1) #Visualizes the null values
# Out:
# <AxesSubplot:>

# %% [markdown]
# The missing numbers are represented by white lines on the visual from missingno.
# “Missing values are the white lines on the visual. We can see that Type.2 and Win_Rate missing values are represented differently. Type 2 and Win_Rate have large portions of missing data.”

# %% [markdown]
# ## b. Dealing with missing values for Type.2 and Win_rate

# %%
## Replace nulls with NaN
##Type 2
df1['Type 2'].replace('', np.NaN)
# Out:
# X.
# 1      Poison
# 2      Poison
# 3      Poison
# 3      Poison
# 4         NaN
#         ...
# 719     Fairy
# 719     Fairy
# 720     Ghost
# 720      Dark
# 721     Water
# Name: Type 2, Length: 800, dtype: object

# %%
## Win_Rate
df1['Win_rate'].replace('NA',np.NaN)
# Out:
# X.
# 1      0.17
# 2      0.36
# 3      0.63
# 3      0.58
# 4      0.48
#        ...
# 719     NaN
# 719     NaN
# 720     NaN
# 720     NaN
# 721     NaN
# Name: Win_rate, Length: 800, dtype: float64

# %% [markdown]
# # TASK 3

# %% [markdown]
# ## a.Using Boxplot to visualize outliers in quantitative variables

# %%
pokemon_stats = df1.drop(['Type 1', 'Type 2', 'Legendary', 'Name', 'Total', 'Generation','Win_rate','Type1_Win_rate'], axis=1)
plt.figure(figsize=(10,5))
sns.boxplot(data=pokemon_stats)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## b. How to handle outliers

# %%
##Drop unnecessary Columns
pokemon_outliers1 = df1.drop(['Type 1', 'Type 2', 'Legendary', 'Name', 'Total', 'Generation','Win_rate','Type1_Win_rate'], axis=1)

pokemon_outliers1
# Out:
#      HP  Attack  Defense  Special_Attack  Special_Defense  Speed
# X.
# 1    45      49       49              65               65     45
# 2    60      62       63              80               80     60
# 3    80      82       83             100              100     80
# 3    80     100      123             122              120     80
# 4    39      52       43              60               50     65
# ..   ..     ...      ...             ...              ...    ...
# 719  50     100      150             100              150     50
# 719  50     160      110             160              110    110
# 720  80     110       60             150              130     70
# 720  80     160       60             170              130     80
# 721  80     110      120             130               90     70
#
# [800 rows x 6 columns]

# %%
pokemon_outliers = pokemon_outliers1.iloc[:,] ##access all the rows and columns as a Boolean array.

pokemon_outliers
# Out:
#      HP  Attack  Defense  Special_Attack  Special_Defense  Speed
# X.
# 1    45      49       49              65               65     45
# 2    60      62       63              80               80     60
# 3    80      82       83             100              100     80
# 3    80     100      123             122              120     80
# 4    39      52       43              60               50     65
# ..   ..     ...      ...             ...              ...    ...
# 719  50     100      150             100              150     50
# 719  50     160      110             160              110    110
# 720  80     110       60             150              130     70
# 720  80     160       60             170              130     80
# 721  80     110      120             130               90     70
#
# [800 rows x 6 columns]

# %%
z_scores = stats.zscore(pokemon_outliers1) #Finding Zscore

# %%
z_scores
# Out:
#            HP    Attack   Defense  Special_Attack  Special_Defense     Speed
# X.
# 1   -0.950626 -0.924906 -0.797154       -0.239130        -0.248189 -0.801503
# 2   -0.362822 -0.524130 -0.347917        0.219560         0.291156 -0.285015
# 3    0.420917  0.092448  0.293849        0.831146         1.010283  0.403635
# 3    0.420917  0.647369  1.577381        1.503891         1.729409  0.403635
# 4   -1.185748 -0.832419 -0.989683       -0.392027        -0.787533 -0.112853
# ..        ...       ...       ...             ...              ...       ...
# 719 -0.754692  0.647369  2.443765        0.831146         2.808099 -0.629341
# 719 -0.754692  2.497104  1.160233        2.665905         1.369846  1.436611
# 720  0.420917  0.955658 -0.444182        2.360112         2.088973  0.059310
# 720  0.420917  2.497104 -0.444182        2.971699         2.088973  0.403635
# 721  0.420917  0.955658  1.481116        1.748526         0.650720  0.059310
#
# [800 rows x 6 columns]

# %%
abs_z_scores = np.abs(z_scores) ## turns all negative values to positive values using abs
abs_z_scores
# Out:
#            HP    Attack   Defense  Special_Attack  Special_Defense     Speed
# X.
# 1    0.950626  0.924906  0.797154        0.239130         0.248189  0.801503
# 2    0.362822  0.524130  0.347917        0.219560         0.291156  0.285015
# 3    0.420917  0.092448  0.293849        0.831146         1.010283  0.403635
# 3    0.420917  0.647369  1.577381        1.503891         1.729409  0.403635
# 4    1.185748  0.832419  0.989683        0.392027         0.787533  0.112853
# ..        ...       ...       ...             ...              ...       ...
# 719  0.754692  0.647369  2.443765        0.831146         2.808099  0.629341
# 719  0.754692  2.497104  1.160233        2.665905         1.369846  1.436611
# 720  0.420917  0.955658  0.444182        2.360112         2.088973  0.059310
# 720  0.420917  2.497104  0.444182        2.971699         2.088973  0.403635
# 721  0.420917  0.955658  1.481116        1.748526         0.650720  0.059310
#
# [800 rows x 6 columns]

# %%
filtered_entries = (abs_z_scores < 3).all ##Filter values that are less than 
filtered_entries
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.all of        HP  Attack  Defense  Special_Attack  Special_Defense  Speed
# X.
# 1    True    True     True            True             True   True
# 2    True    True     True            True             True   True
# 3    True    True     True            True             True   True
# 3    True    True     True            True             True   True
# 4    True    True     True            True             True   True
# ..    ...     ...      ...             ...              ...    ...
# 719  True    True     True            True             True   True
# 719  True    True     True            True             True   True
# 720  True    True     True            True             True   True
# 720  True    True     True            True             True   True
# 721  True    True     True            True             True   True
#
# [800 rows x 6 columns]>

# %%
z=np.abs(stats.zscore(pokemon_outliers1))
z
# Out:
#            HP    Attack   Defense  Special_Attack  Special_Defense     Speed
# X.
# 1    0.950626  0.924906  0.797154        0.239130         0.248189  0.801503
# 2    0.362822  0.524130  0.347917        0.219560         0.291156  0.285015
# 3    0.420917  0.092448  0.293849        0.831146         1.010283  0.403635
# 3    0.420917  0.647369  1.577381        1.503891         1.729409  0.403635
# 4    1.185748  0.832419  0.989683        0.392027         0.787533  0.112853
# ..        ...       ...       ...             ...              ...       ...
# 719  0.754692  0.647369  2.443765        0.831146         2.808099  0.629341
# 719  0.754692  2.497104  1.160233        2.665905         1.369846  1.436611
# 720  0.420917  0.955658  0.444182        2.360112         2.088973  0.059310
# 720  0.420917  2.497104  0.444182        2.971699         2.088973  0.403635
# 721  0.420917  0.955658  1.481116        1.748526         0.650720  0.059310
#
# [800 rows x 6 columns]

# %%
np.where(z > 3) ## List of outliers
# Out:
# (array([ 71,  87,  98, 121, 155, 163, 164, 217, 223, 224, 230, 230, 232,
#         261, 313, 315, 332, 333, 351, 414, 415, 422, 422, 424, 426, 426,
#         429, 429, 430, 431, 456, 473, 544, 545, 655, 789], dtype=int64),
#  array([3, 2, 2, 0, 0, 1, 3, 0, 2, 2, 2, 4, 1, 0, 0, 5, 2, 2, 0, 2, 4, 3,
#         4, 1, 1, 3, 1, 3, 4, 5, 2, 0, 0, 0, 0, 2], dtype=int64))

# %%
z_pokemons = pokemon_outliers[(z < 3).all(axis=1)] ## list of scores that has zscore less than 3
#Comparing shape before and after
pokemon_outliers.shape,z_pokemons[['HP','Attack','Defense','Special_Attack','Special_Defense','Speed']].shape
# Out:
# ((800, 6), (768, 6))

# %%
##After dealing with outliers
plt.figure(figsize=(10,5))
sns.boxplot(data=z_pokemons)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## b.Checking descriptive statistics

# %%
pokemon_stats.describe()
# Out:
#                HP      Attack     Defense  Special_Attack  Special_Defense  \
# count  800.000000  800.000000  800.000000      800.000000       800.000000
# mean    69.258750   79.001250   73.842500       72.820000        71.902500
# std     25.534669   32.457366   31.183501       32.722294        27.828916
# min      1.000000    5.000000    5.000000       10.000000        20.000000
# 25%     50.000000   55.000000   50.000000       49.750000        50.000000
# 50%     65.000000   75.000000   70.000000       65.000000        70.000000
# 75%     80.000000  100.000000   90.000000       95.000000        90.000000
# max    255.000000  190.000000  230.000000      194.000000       230.000000
#
#             Speed
# count  800.000000
# mean    68.277500
# std     29.060474
# min      5.000000
# 25%     45.000000
# 50%     65.000000
# 75%     90.000000
# max    180.000000

# %%
pokemon_stats.mean()
# Out:
# HP                 69.25875
# Attack             79.00125
# Defense            73.84250
# Special_Attack     72.82000
# Special_Defense    71.90250
# Speed              68.27750
# dtype: float64

# %%
pokemon_stats.median()
# Out:
# HP                 65.0
# Attack             75.0
# Defense            70.0
# Special_Attack     65.0
# Special_Defense    70.0
# Speed              65.0
# dtype: float64

# %% [markdown]
# # TASK 4

# %% [markdown]
# ## Analyzing association between two variables

# %% [markdown]
# ## a. Finding most common and uncommon Pokemons

# %% [markdown]
# TYPE 1

# %%
plt.figure(figsize=(13,6))
sns.countplot(df1['Type 1'])
# Out:
# C:\Users\Sonika\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Type 1', ylabel='count'>

# %% [markdown]
# TYPE 2

# %%
plt.figure(figsize=(13,6))
sns.countplot(df1['Type 2'])
# Out:
# C:\Users\Sonika\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Type 2', ylabel='count'>

# %% [markdown]
# ## b. Generation with maximum Pokemons

# %%
df2=pd.DataFrame(data=df1, columns=['Generation']) ##list only from Generation columns
df2.groupby(['Generation'])['Generation'].count() ## Group by Generation --counts number of each generation
# Out:
# Generation
# 1    166
# 2    106
# 3    160
# 4    121
# 5    165
# 6     82
# Name: Generation, dtype: int64

# %%
plt.figure(figsize=(5,5))
sns.countplot(df2['Generation'])
# Out:
# C:\Users\Sonika\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Generation', ylabel='count'>

# %% [markdown]
# ## c. Generation that has maximum Legendary Pokemons

# %%
Legendary_True = df1[df1['Legendary'] == True] ##list only from Legendary columns that's true
max_Gen = Legendary_True.groupby(['Generation'])['Legendary'].count() ## Group by Generation --counts number of each generation with true Legendary

# %%
max_Gen.sort_values( ascending=False) ## max count first
# Out:
# Generation
# 3    18
# 5    15
# 4    13
# 6     8
# 1     6
# 2     5
# Name: Legendary, dtype: int64

# %% [markdown]
# ## d. Types of Pokemons that are most speedy

# %%
most_speed = df1['Speed'].max() #Finds out the highest speed
df1[['Type 1','Type 2','Speed']][df1.Speed== most_speed] # finds out the type of the highest speed pokemon
# Out:
#       Type 1 Type 2  Speed
# X.
# 386  Psychic    NaN    180

# %%
##Lsit to show the most speedy 
Speed = df1.sort_values(by='Speed', ascending=False) #sorting the rows in descending order 

Speed.drop_duplicates(subset=['Type 1'],keep='first')
# Out:
#                   Name    Type 1    Type 2  Total   HP  Attack  Defense  \
# X.
# 386  DeoxysSpeed Forme   Psychic       NaN    600   50      95       90
# 291            Ninjask       Bug    Flying    456   61      90       45
# 142    Mega Aerodactyl      Rock    Flying    615   80     135       85
# 254      Mega Sceptile     Grass    Dragon    630   70     110       75
# 101          Electrode  Electric       NaN    480   60      50       70
# 428       Mega Lopunny    Normal  Fighting    580   65     136       94
# 169             Crobat    Poison    Flying    535   85      90       80
# 94         Mega Gengar     Ghost    Poison    600   60      65       80
# 663         Talonflame      Fire    Flying    499   78      81       71
# 491            Darkrai      Dark       NaN    600   70      90       90
# 715            Noivern    Flying    Dragon    535   85      70       80
# 658           Greninja     Water      Dark    530   72      95       67
# 373     Mega Salamence    Dragon    Flying    700   95     145      130
# 51             Dugtrio    Ground       NaN    405   35      80       50
# 701           Hawlucha  Fighting    Flying    500   78      92       75
# 478           Froslass       Ice     Ghost    480   70      80       70
# 376     Mega Metagross     Steel   Psychic    700   80     145      150
# 716            Xerneas     Fairy       NaN    680  126     131       95
#
#      Special_Attack  Special_Defense  Speed  Generation  Legendary  Win_rate  \
# X.
# 386              95               90    180           3       True      0.89
# 291              50               50    160           3      False      0.92
# 142              70               95    150           1      False      0.98
# 254             145               85    145           3      False      0.96
# 101              80               80    140           1      False      0.83
# 428              54               96    135           4      False      0.94
# 169              70               80    130           2      False      0.89
# 94              170               95    130           1      False      0.88
# 663              74               69    126           6      False       NaN
# 491             135               90    125           4       True      0.93
# 715              97               80    123           6      False       NaN
# 658             103               71    122           6      False       NaN
# 373             120               90    120           3      False      0.92
# 51               50               70    120           1      False      0.88
# 701              74               63    118           6      False       NaN
# 478              80               70    110           4      False      0.35
# 376             105              110    110           3      False      0.81
# 716             131               98     99           6       True       NaN
#
#      Type1_Win_rate
# X.
# 386        0.400652
# 291        0.493884
# 142        0.519051
# 254        0.446002
# 101        0.444901
# 428        0.481159
# 169        0.521609
# 94         0.555501
# 663        0.441195
# 491        0.489887
# 715        0.497487
# 658        0.495605
# 373        0.522461
# 51         0.447482
# 701        0.474696
# 478        0.463466
# 376        0.370264
# 716        0.363225

# %%
Highest_Win_Rate = df1['Win_rate'].max() ##Finds out the max Speed

# %%
max_win_rate_Pokemons = df1[df1['Win_rate'] == Highest_Win_Rate ] ## List pokemons df with max win rate
max_win_rate_Pokemons[['Name','Type 1','Type 2']] ## Lists name and type of Pokemons with highest win rate
# Out:
#                 Name Type 1  Type 2
# X.
# 142  Mega Aerodactyl   Rock  Flying

# %%
Win_rate = df1.sort_values(by='Win_rate', ascending=False) #sorting the rows in descending order 

Win_rate.drop_duplicates(subset=['Type 1'],keep='first')
# Out:
#                         Name    Type 1    Type 2  Total   HP  Attack  Defense  \
# X.
# 142          Mega Aerodactyl      Rock    Flying    615   80     135       85
# 461                  Weavile      Dark       Ice    510   70     120       65
# 15             Mega Beedrill       Bug    Poison    495   65     150       40
# 254            Mega Sceptile     Grass    Dragon    630   70     110       75
# 150            Mega Mewtwo X   Psychic  Fighting    780  106     190      100
# 384            Mega Rayquaza    Dragon    Flying    780  105     180      100
# 641    TornadusTherian Forme    Flying       NaN    580   79     100       80
# 135                  Jolteon  Electric       NaN    525   65      65       60
# 428             Mega Lopunny    Normal  Fighting    580   65     136       94
# 647     KeldeoResolute Forme     Water  Fighting    580   91      72       90
# 620                 Mienshao  Fighting       NaN    510   65     125       60
# 638                 Cobalion     Steel  Fighting    580   91      90      129
# 392                Infernape      Fire  Fighting    534   76     104       71
# 645  LandorusIncarnate Forme    Ground    Flying    600   89     125       90
# 169                   Crobat    Poison    Flying    535   85      90       80
# 94               Mega Gengar     Ghost    Poison    600   60      65       80
# 362              Mega Glalie       Ice       NaN    580   80     120       80
# 468                 Togekiss     Fairy    Flying    545   85      50       95
#
#      Special_Attack  Special_Defense  Speed  Generation  Legendary  Win_rate  \
# X.
# 142              70               95    150           1      False      0.98
# 461              45               85    125           4      False      0.97
# 15               15               80    145           1      False      0.96
# 254             145               85    145           3      False      0.96
# 150             154              100    130           1       True      0.95
# 384             180              100    115           3       True      0.95
# 641             110               90    121           5       True      0.95
# 135             110               95    130           1      False      0.95
# 428              54               96    135           4      False      0.94
# 647             129               90    108           5      False      0.94
# 620              95               60    105           5      False      0.94
# 638              90               72    108           5       True      0.93
# 392             104               71    108           4      False      0.91
# 645             115               80    101           5       True      0.90
# 169              70               80    130           2      False      0.89
# 94              170               95    130           1      False      0.88
# 362             120               80    100           3      False      0.82
# 468             120              115     80           4      False      0.52
#
#      Type1_Win_rate
# X.
# 142        0.519051
# 461        0.489887
# 15         0.493884
# 254        0.446002
# 150        0.400652
# 384        0.522461
# 641        0.497487
# 135        0.444901
# 428        0.481159
# 647        0.495605
# 620        0.474696
# 638        0.370264
# 392        0.441195
# 645        0.447482
# 169        0.521609
# 94         0.555501
# 362        0.463466
# 468        0.363225

# %% [markdown]
# ## Checking correlations between Win_rate and other variables

# %% [markdown]
# From the correlation chart below, we can say that Win_Rate and Speed are correlated. Therefore, when the speed is high the Win_rate is high as well and vice versa

# %%
pokemon_correlation = df1.drop(['Type 1', 'Type 2', 'Legendary', 'Name', 'Total', 'Generation'], axis=1) #Drop unnecessary column
plt.figure(figsize=(10,5)) #manage the size of the plot
sns.heatmap(pokemon_correlation.corr(),annot=True) #pokemon.col() makes a correlation matrix and sns.heatmap is used to show the correlations heatmap
plt.show()

# %% [markdown]
# ## Correlation between Attack and Defense

# %% [markdown]
# From the correlation chart below, we can say that Attack and Defense are not correlated. Therefore, when the Attack is at high the Defense is at its low and vice versa.

# %%
pokemon_col = df1.drop(['Type 1', 'Type 2', 'Legendary', 'Total', 'Generation','HP','Special_Attack','Special_Defense','Speed','Win_rate','Type1_Win_rate'], axis=1)
plt.figure(figsize=(10,5)) #manage the size of the plot
sns.heatmap(pokemon_col.corr(),annot=True) #pokemon.col() makes a correlation matrix and sns.heatmap is used to show the correlations heatmap
plt.show()

# %%
pokemon_col = df1.drop(['Total', 'Legendary','HP', 'Special_Attack', 'Special_Defense', 'Speed','Type1_Win_rate', 'Generation'], axis=1) 

Attack = pokemon_col.sort_values(by='Attack', ascending=False) #sorting the rows in descending order 

Attack.drop_duplicates(subset=['Type 1'],keep='first')
# Out:
#                         Name    Type 1    Type 2  Attack  Defense  Win_rate
# X.
# 150            Mega Mewtwo X   Psychic  Fighting     190      100      0.95
# 214           Mega Heracross       Bug  Fighting     185      115      0.57
# 383    GroudonPrimal Groudon    Ground      Fire     180      160      0.77
# 384            Mega Rayquaza    Dragon    Flying     180      100      0.95
# 354             Mega Banette     Ghost       NaN     165       75      0.63
# 409                Rampardos      Rock       NaN     165       60      0.33
# 289                  Slaking    Normal       NaN     160      100      0.83
# 257            Mega Blaziken      Fire  Fighting     160       80      0.84
# 130            Mega Gyarados     Water      Dark     155      109      0.69
# 359               Mega Absol      Dark       NaN     150       60      0.93
# 681     AegislashBlade Forme     Steel     Ghost     150       50       NaN
# 448             Mega Lucario  Fighting     Steel     145       88      0.86
# 460           Mega Abomasnow     Grass       Ice     132      105      0.44
# 716                  Xerneas     Fairy       NaN     131       95       NaN
# 473                Mamoswine       Ice    Ground     130       80      0.63
# 466               Electivire  Electric       NaN     123       67      0.77
# 641  TornadusIncarnate Forme    Flying       NaN     115       70      0.84
# 454                Toxicroak    Poison  Fighting     106       65      0.60

# %%
pokemon_col = df1.drop(['Total', 'Legendary','HP', 'Special_Attack', 'Special_Defense', 'Speed','Type1_Win_rate', 'Generation'], axis=1) 

Defense = pokemon_col.sort_values(by='Defense', ascending=False) #sorting the rows in descending order 

Defense.drop_duplicates(subset=['Type 1'],keep='first')
# Out:
#                       Name    Type 1  Type 2  Attack  Defense  Win_rate
# X.
# 213                Shuckle       Bug    Rock      10      230      0.00
# 208           Mega Steelix     Steel  Ground     125      230      0.25
# 377               Regirock      Rock     NaN     100      200      0.30
# 713                Avalugg       Ice     NaN     117      184       NaN
# 91                Cloyster     Water     Ice      95      180      0.53
# 383  GroudonPrimal Groudon    Ground    Fire     180      160      0.77
# 386    DeoxysDefense Forme   Psychic     NaN      70      160      0.73
# 563             Cofagrigus     Ghost     NaN      50      145      0.11
# 324                Torkoal      Fire     NaN      85      140      0.32
# 598             Ferrothorn     Grass   Steel      94      131      0.42
# 373         Mega Salamence    Dragon  Flying     145      130      0.92
# 531            Mega Audino    Normal   Fairy      60      126      0.30
# 302           Mega Sableye      Dark   Ghost      85      125      0.15
# 110                Weezing    Poison     NaN      90      120      0.37
# 462              Magnezone  Electric   Steel      70      115      0.46
# 237              Hitmontop  Fighting     NaN      95       95      0.52
# 716                Xerneas     Fairy     NaN     131       95       NaN
# 715                Noivern    Flying  Dragon      70       80       NaN
