# %%
import pandas as pd

# %%
import missingno as msno

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv(r'/Users/aynuraberdyyeva/Desktop/project1_ds.csv')
df
# Out:
#      Unnamed: 0   X.                   Name   Type.1  Type.2  Total  HP  \
# 0             1    1              Bulbasaur    Grass  Poison    318  45
# 1             2    2                Ivysaur    Grass  Poison    405  60
# 2             3    3               Venusaur    Grass  Poison    525  80
# 3             4    3  VenusaurMega Venusaur    Grass  Poison    625  80
# 4             5    4             Charmander     Fire     NaN    309  39
# ..          ...  ...                    ...      ...     ...    ...  ..
# 795         796  719                Diancie     Rock   Fairy    600  50
# 796         797  719    DiancieMega Diancie     Rock   Fairy    700  50
# 797         798  720    HoopaHoopa Confined  Psychic   Ghost    600  80
# 798         799  720     HoopaHoopa Unbound  Psychic    Dark    680  80
# 799         800  721              Volcanion     Fire   Water    600  80
#
#      Attack  Defense  Sp..Atk  Sp..Def  Speed  Generation  Legendary  \
# 0        49       49       65       65     45           1      False
# 1        62       63       80       80     60           1      False
# 2        82       83      100      100     80           1      False
# 3       100      123      122      120     80           1      False
# 4        52       43       60       50     65           1      False
# ..      ...      ...      ...      ...    ...         ...        ...
# 795     100      150      100      150     50           6       True
# 796     160      110      160      110    110           6       True
# 797     110       60      150      130     70           6       True
# 798     160       60      170      130     80           6       True
# 799     110      120      130       90     70           6       True
#
#      Win_rate  Type1_Win_rate
# 0        0.17        0.446002
# 1        0.36        0.446002
# 2        0.63        0.446002
# 3        0.58        0.446002
# 4        0.48        0.441195
# ..        ...             ...
# 795       NaN        0.519051
# 796       NaN        0.519051
# 797       NaN        0.400652
# 798       NaN        0.400652
# 799       NaN        0.441195
#
# [800 rows x 16 columns]

# %%
df.shape
(800, 16)
# Out:
# (800, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      800 non-null    int64
#  1   X.              800 non-null    int64
#  2   Name            800 non-null    object
#  3   Type.1          800 non-null    object
#  4   Type.2          414 non-null    object
#  5   Total           800 non-null    int64
#  6   HP              800 non-null    int64
#  7   Attack          800 non-null    int64
#  8   Defense         800 non-null    int64
#  9   Sp..Atk         800 non-null    int64
#  10  Sp..Def         800 non-null    int64
#  11  Speed           800 non-null    int64
#  12  Generation      800 non-null    int64
#  13  Legendary       800 non-null    bool
#  14  Win_rate        706 non-null    float64
#  15  Type1_Win_rate  800 non-null    float64
# dtypes: bool(1), float64(2), int64(10), object(3)
# memory usage: 94.7+ KB

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Length: 800, dtype: bool

# %%
df1 = df.drop({'Unnamed: 0',\
              'X.'}, axis = 1)
df1
# Out:
#                       Name   Type.1  Type.2  Total  HP  Attack  Defense  \
# 0                Bulbasaur    Grass  Poison    318  45      49       49
# 1                  Ivysaur    Grass  Poison    405  60      62       63
# 2                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 795                Diancie     Rock   Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799              Volcanion     Fire   Water    600  80     110      120
#
#      Sp..Atk  Sp..Def  Speed  Generation  Legendary  Win_rate  Type1_Win_rate
# 0         65       65     45           1      False      0.17        0.446002
# 1         80       80     60           1      False      0.36        0.446002
# 2        100      100     80           1      False      0.63        0.446002
# 3        122      120     80           1      False      0.58        0.446002
# 4         60       50     65           1      False      0.48        0.441195
# ..       ...      ...    ...         ...        ...       ...             ...
# 795      100      150     50           6       True       NaN        0.519051
# 796      160      110    110           6       True       NaN        0.519051
# 797      150      130     70           6       True       NaN        0.400652
# 798      170      130     80           6       True       NaN        0.400652
# 799      130       90     70           6       True       NaN        0.441195
#
# [800 rows x 14 columns]

# %%
df1.rename({'Type.1': 'Type 1', \
           'Type.2': 'Type 2',\
           'Sp..Atk': 'Special_Attack',\
           'Sp..Def': 'Special_Defense'}, axis=1, inplace=True)
df1
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0                Bulbasaur    Grass  Poison    318  45      49       49
# 1                  Ivysaur    Grass  Poison    405  60      62       63
# 2                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 795                Diancie     Rock   Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799              Volcanion     Fire   Water    600  80     110      120
#
#      Special_Attack  Special_Defense  Speed  Generation  Legendary  Win_rate  \
# 0                65               65     45           1      False      0.17
# 1                80               80     60           1      False      0.36
# 2               100              100     80           1      False      0.63
# 3               122              120     80           1      False      0.58
# 4                60               50     65           1      False      0.48
# ..              ...              ...    ...         ...        ...       ...
# 795             100              150     50           6       True       NaN
# 796             160              110    110           6       True       NaN
# 797             150              130     70           6       True       NaN
# 798             170              130     80           6       True       NaN
# 799             130               90     70           6       True       NaN
#
#      Type1_Win_rate
# 0          0.446002
# 1          0.446002
# 2          0.446002
# 3          0.446002
# 4          0.441195
# ..              ...
# 795        0.519051
# 796        0.519051
# 797        0.400652
# 798        0.400652
# 799        0.441195
#
# [800 rows x 14 columns]

# %%
import regex as re 
df1.Name = df1.Name.apply(lambda x: re.sub(r'(.+)(Mega.+)',r'\2', x))
df1.head()
# Out:
#             Name Type 1  Type 2  Total  HP  Attack  Defense  Special_Attack  \
# 0      Bulbasaur  Grass  Poison    318  45      49       49              65
# 1        Ivysaur  Grass  Poison    405  60      62       63              80
# 2       Venusaur  Grass  Poison    525  80      82       83             100
# 3  Mega Venusaur  Grass  Poison    625  80     100      123             122
# 4     Charmander   Fire     NaN    309  39      52       43              60
#
#    Special_Defense  Speed  Generation  Legendary  Win_rate  Type1_Win_rate
# 0               65     45           1      False      0.17        0.446002
# 1               80     60           1      False      0.36        0.446002
# 2              100     80           1      False      0.63        0.446002
# 3              120     80           1      False      0.58        0.446002
# 4               50     65           1      False      0.48        0.441195

# %%
df1.dtypes
# Out:
# Name                object
# Type 1              object
# Type 2              object
# Total                int64
# HP                   int64
# Attack               int64
# Defense              int64
# Special_Attack       int64
# Special_Defense      int64
# Speed                int64
# Generation           int64
# Legendary             bool
# Win_rate           float64
# Type1_Win_rate     float64
# dtype: object

# %%
df1.isna().sum()
# Out:
# Name                 0
# Type 1               0
# Type 2             386
# Total                0
# HP                   0
# Attack               0
# Defense              0
# Special_Attack       0
# Special_Defense      0
# Speed                0
# Generation           0
# Legendary            0
# Win_rate            94
# Type1_Win_rate       0
# dtype: int64

# %%
msno.matrix(df1)
# Out:
# <AxesSubplot:>

# %%
import numpy as np
df1['Win_rate'].replace('NA', np.NaN)
# Out:
# 0      0.17
# 1      0.36
# 2      0.63
# 3      0.58
# 4      0.48
#        ...
# 795     NaN
# 796     NaN
# 797     NaN
# 798     NaN
# 799     NaN
# Name: Win_rate, Length: 800, dtype: float64

# %%
df1['Type 2'].replace('', np.NaN)
# Out:
# 0      Poison
# 1      Poison
# 2      Poison
# 3      Poison
# 4         NaN
#         ...
# 795     Fairy
# 796     Fairy
# 797     Ghost
# 798      Dark
# 799     Water
# Name: Type 2, Length: 800, dtype: object

# %%
pokemon_stats = df1.drop(['Type 1', 'Type 2', 'Legendary', 'Name', 'Total', 'Generation', 'Win_rate', 'Type1_Win_rate'], axis=1)
plt.figure(figsize=(10,5))  
sns.boxplot(data=pokemon_stats)
# Out:
# <AxesSubplot:>

# %%
print(np.where(df1['HP']>135))
# Out:
# (array([ 45, 121, 155, 217, 261, 313, 321, 351, 473, 544, 545, 655]),)

# %%
print(np.where(df1['HP']<5))
# Out:
# (array([316]),)

# %%
print(np.where(df1['Attack']>170))
# Out:
# (array([163, 232, 424, 426, 429]),)

# %%
print(np.where(df1['Defense']>155))
# Out:
# (array([ 87,  98, 103, 223, 224, 230, 332, 333, 414, 424, 430, 456, 789]),)

# %%
print(np.where(df1['Special_Attack']>170))
# Out:
# (array([ 71, 164, 422, 426, 429]),)

# %%
print(np.where(df1['Speed']>150))
# Out:
# (array([315, 431]),)

# %%
print(np.where(df1['Special_Defense']>155))
# Out:
# (array([230, 415, 422, 430]),)

# %%
df1_summary = df1.describe() #summary of the pokemon dataframe
df1_summary
# Out:
#            Total          HP      Attack     Defense  Special_Attack  \
# count  800.00000  800.000000  800.000000  800.000000      800.000000
# mean   435.10250   69.258750   79.001250   73.842500       72.820000
# std    119.96304   25.534669   32.457366   31.183501       32.722294
# min    180.00000    1.000000    5.000000    5.000000       10.000000
# 25%    330.00000   50.000000   55.000000   50.000000       49.750000
# 50%    450.00000   65.000000   75.000000   70.000000       65.000000
# 75%    515.00000   80.000000  100.000000   90.000000       95.000000
# max    780.00000  255.000000  190.000000  230.000000      194.000000
#
#        Special_Defense       Speed  Generation    Win_rate  Type1_Win_rate
# count       800.000000  800.000000   800.00000  706.000000      800.000000
# mean         71.902500   68.277500     3.32375    0.473810        0.471075
# std          27.828916   29.060474     1.66129    0.266284        0.043434
# min          20.000000    5.000000     1.00000    0.000000        0.363225
# 25%          50.000000   45.000000     2.00000    0.240000        0.446002
# 50%          70.000000   65.000000     3.00000    0.460000        0.481159
# 75%          90.000000   90.000000     5.00000    0.700000        0.495605
# max         230.000000  180.000000     6.00000    0.980000        0.555501

# %%
plt.figure(figsize=(13,6))
sns.countplot(df1['Type 1'])
# Out:
# /Users/aynuraberdyyeva/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Type 1', ylabel='count'>

# %%
plt.figure(figsize=(13,6))
sns.countplot(df1['Type 2'])
# Out:
# /Users/aynuraberdyyeva/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Type 2', ylabel='count'>

# %%
df2=pd.DataFrame(data=df1, columns=['Generation'])
df2.groupby(['Generation'])['Generation'].count()
# Out:
# Generation
# 1    166
# 2    106
# 3    160
# 4    121
# 5    165
# 6     82
# Name: Generation, dtype: int64

# %%
Legendary_True = df1[df1['Legendary'] == True]
Legendary_True.groupby(['Generation'])['Legendary'].count()
# Out:
# Generation
# 1     6
# 2     5
# 3    18
# 4    13
# 5    15
# 6     8
# Name: Legendary, dtype: int64

# %%
max_Speed_pokemons = df1[['Type 1','Speed']][df1.Speed==df1['Speed'].max()]
max_Speed_pokemons
# Out:
#       Type 1  Speed
# 431  Psychic    180

# %%
Speed = df1.sort_values(by='Speed', ascending=False) #sorting the rows in descending order
Speed.drop_duplicates(subset=['Type 1'],keep='first')
# Out:
#                   Name    Type 1    Type 2  Total   HP  Attack  Defense  \
# 431  DeoxysSpeed Forme   Psychic       NaN    600   50      95       90
# 315            Ninjask       Bug    Flying    456   61      90       45
# 154    Mega Aerodactyl      Rock    Flying    615   80     135       85
# 275      Mega Sceptile     Grass    Dragon    630   70     110       75
# 109          Electrode  Electric       NaN    480   60      50       70
# 476       Mega Lopunny    Normal  Fighting    580   65     136       94
# 183             Crobat    Poison    Flying    535   85      90       80
# 102        Mega Gengar     Ghost    Poison    600   60      65       80
# 731         Talonflame      Fire    Flying    499   78      81       71
# 549            Darkrai      Dark       NaN    600   70      90       90
# 791            Noivern    Flying    Dragon    535   85      70       80
# 726           Greninja     Water      Dark    530   72      95       67
# 409     Mega Salamence    Dragon    Flying    700   95     145      130
# 56             Dugtrio    Ground       NaN    405   35      80       50
# 771           Hawlucha  Fighting    Flying    500   78      92       75
# 530           Froslass       Ice     Ghost    480   70      80       70
# 413     Mega Metagross     Steel   Psychic    700   80     145      150
# 792            Xerneas     Fairy       NaN    680  126     131       95
#
#      Special_Attack  Special_Defense  Speed  Generation  Legendary  Win_rate  \
# 431              95               90    180           3       True      0.89
# 315              50               50    160           3      False      0.92
# 154              70               95    150           1      False      0.98
# 275             145               85    145           3      False      0.96
# 109              80               80    140           1      False      0.83
# 476              54               96    135           4      False      0.94
# 183              70               80    130           2      False      0.89
# 102             170               95    130           1      False      0.88
# 731              74               69    126           6      False       NaN
# 549             135               90    125           4       True      0.93
# 791              97               80    123           6      False       NaN
# 726             103               71    122           6      False       NaN
# 409             120               90    120           3      False      0.92
# 56               50               70    120           1      False      0.88
# 771              74               63    118           6      False       NaN
# 530              80               70    110           4      False      0.35
# 413             105              110    110           3      False      0.81
# 792             131               98     99           6       True       NaN
#
#      Type1_Win_rate
# 431        0.400652
# 315        0.493884
# 154        0.519051
# 275        0.446002
# 109        0.444901
# 476        0.481159
# 183        0.521609
# 102        0.555501
# 731        0.441195
# 549        0.489887
# 791        0.497487
# 726        0.495605
# 409        0.522461
# 56         0.447482
# 771        0.474696
# 530        0.463466
# 413        0.370264
# 792        0.363225

# %%
max_Win_rate_pokemons = df1[['Type 1','Win_rate']][df1.Win_rate==df1['Win_rate'].max()]
max_Win_rate_pokemons
# Out:
#     Type 1  Win_rate
# 154   Rock      0.98

# %%
Win_rate = df1.sort_values(by='Win_rate', ascending=False) #sorting the rows in descending order
Win_rate.drop_duplicates(subset=['Type 1'],keep='first')
# Out:
#                         Name    Type 1    Type 2  Total   HP  Attack  Defense  \
# 154          Mega Aerodactyl      Rock    Flying    615   80     135       85
# 512                  Weavile      Dark       Ice    510   70     120       65
# 19             Mega Beedrill       Bug    Poison    495   65     150       40
# 275            Mega Sceptile     Grass    Dragon    630   70     110       75
# 163            Mega Mewtwo X   Psychic  Fighting    780  106     190      100
# 426            Mega Rayquaza    Dragon    Flying    780  105     180      100
# 703    TornadusTherian Forme    Flying       NaN    580   79     100       80
# 146                  Jolteon  Electric       NaN    525   65      65       60
# 476             Mega Lopunny    Normal  Fighting    580   65     136       94
# 714     KeldeoResolute Forme     Water  Fighting    580   91      72       90
# 681                 Mienshao  Fighting       NaN    510   65     125       60
# 699                 Cobalion     Steel  Fighting    580   91      90      129
# 437                Infernape      Fire  Fighting    534   76     104       71
# 708  LandorusIncarnate Forme    Ground    Flying    600   89     125       90
# 183                   Crobat    Poison    Flying    535   85      90       80
# 102              Mega Gengar     Ghost    Poison    600   60      65       80
# 397              Mega Glalie       Ice       NaN    580   80     120       80
# 519                 Togekiss     Fairy    Flying    545   85      50       95
#
#      Special_Attack  Special_Defense  Speed  Generation  Legendary  Win_rate  \
# 154              70               95    150           1      False      0.98
# 512              45               85    125           4      False      0.97
# 19               15               80    145           1      False      0.96
# 275             145               85    145           3      False      0.96
# 163             154              100    130           1       True      0.95
# 426             180              100    115           3       True      0.95
# 703             110               90    121           5       True      0.95
# 146             110               95    130           1      False      0.95
# 476              54               96    135           4      False      0.94
# 714             129               90    108           5      False      0.94
# 681              95               60    105           5      False      0.94
# 699              90               72    108           5       True      0.93
# 437             104               71    108           4      False      0.91
# 708             115               80    101           5       True      0.90
# 183              70               80    130           2      False      0.89
# 102             170               95    130           1      False      0.88
# 397             120               80    100           3      False      0.82
# 519             120              115     80           4      False      0.52
#
#      Type1_Win_rate
# 154        0.519051
# 512        0.489887
# 19         0.493884
# 275        0.446002
# 163        0.400652
# 426        0.522461
# 703        0.497487
# 146        0.444901
# 476        0.481159
# 714        0.495605
# 681        0.474696
# 699        0.370264
# 437        0.441195
# 708        0.447482
# 183        0.521609
# 102        0.555501
# 397        0.463466
# 519        0.363225

# %%
pokemon_col = df1.drop(['Type 1', 'Type 2', 'Legendary', 'Name', 'Total', 'Generation'], axis=1)
plt.figure(figsize=(10,5)) #manage the size of the plot
sns.heatmap(pokemon_col.corr(),annot=True) #pokemon.col() makes a correlation matrix and sns.heatmap is used to show the correlations heatmap
plt.show()

# %%
sns.scatterplot(data = df1, x = df1['Win_rate'], y = df1['Speed'], hue = 'Legendary', palette="deep")
df1['Win_rate'].corr(df1['Speed'])
# Out:
# 0.9244079116432785

# %%
sns.scatterplot(data = df1, x = df1['Attack'], y = df1['Defense'], hue = 'Legendary', palette="deep")
df1['Attack'].corr(df1['Defense'])
# Out:
# 0.4386870551184896

# %%
pokemon_col = df1.drop(['Total', 'Legendary','HP', 'Special_Attack', 'Special_Defense', 'Speed','Type1_Win_rate', 'Generation'], axis=1)
Attack = pokemon_col.sort_values(by='Attack', ascending=False) #sorting the rows in descending order
Attack.drop_duplicates(subset=['Type 1'],keep='first')
# Out:
#                         Name    Type 1    Type 2  Attack  Defense  Win_rate
# 163            Mega Mewtwo X   Psychic  Fighting     190      100      0.95
# 232           Mega Heracross       Bug  Fighting     185      115      0.57
# 424    GroudonPrimal Groudon    Ground      Fire     180      160      0.77
# 426            Mega Rayquaza    Dragon    Flying     180      100      0.95
# 387             Mega Banette     Ghost       NaN     165       75      0.63
# 454                Rampardos      Rock       NaN     165       60      0.33
# 313                  Slaking    Normal       NaN     160      100      0.83
# 279            Mega Blaziken      Fire  Fighting     160       80      0.84
# 141            Mega Gyarados     Water      Dark     155      109      0.69
# 393               Mega Absol      Dark       NaN     150       60      0.93
# 750     AegislashBlade Forme     Steel     Ghost     150       50       NaN
# 498             Mega Lucario  Fighting     Steel     145       88      0.86
# 511           Mega Abomasnow     Grass       Ice     132      105      0.44
# 792                  Xerneas     Fairy       NaN     131       95       NaN
# 524                Mamoswine       Ice    Ground     130       80      0.63
# 517               Electivire  Electric       NaN     123       67      0.77
# 702  TornadusIncarnate Forme    Flying       NaN     115       70      0.84
# 504                Toxicroak    Poison  Fighting     106       65      0.60

# %%
pokemon_col = df1.drop(['Total', 'Legendary','HP', 'Special_Attack', 'Special_Defense', 'Speed','Type1_Win_rate', 'Generation'], axis=1)
Defense = pokemon_col.sort_values(by='Defense', ascending=False) #sorting the rows in descending order
Defense.drop_duplicates(subset=['Type 1'],keep='first')
# Out:
#                       Name    Type 1  Type 2  Attack  Defense  Win_rate
# 230                Shuckle       Bug    Rock      10      230      0.00
# 224           Mega Steelix     Steel  Ground     125      230      0.25
# 414               Regirock      Rock     NaN     100      200      0.30
# 789                Avalugg       Ice     NaN     117      184       NaN
# 98                Cloyster     Water     Ice      95      180      0.53
# 424  GroudonPrimal Groudon    Ground    Fire     180      160      0.77
# 430    DeoxysDefense Forme   Psychic     NaN      70      160      0.73
# 624             Cofagrigus     Ghost     NaN      50      145      0.11
# 355                Torkoal      Fire     NaN      85      140      0.32
# 659             Ferrothorn     Grass   Steel      94      131      0.42
# 409         Mega Salamence    Dragon  Flying     145      130      0.92
# 591            Mega Audino    Normal   Fairy      60      126      0.30
# 327           Mega Sableye      Dark   Ghost      85      125      0.15
# 118                Weezing    Poison     NaN      90      120      0.37
# 513              Magnezone  Electric   Steel      70      115      0.46
# 256              Hitmontop  Fighting     NaN      95       95      0.52
# 792                Xerneas     Fairy     NaN     131       95       NaN
# 791                Noivern    Flying  Dragon      70       80       NaN

# %%
sns.scatterplot(data = df1, x = df1['Attack'], y = df1['Defense'], hue = 'Legendary', palette="deep")
df1['Attack'].corr(df1['Defense'])
# Out:
# 0.4386870551184896
